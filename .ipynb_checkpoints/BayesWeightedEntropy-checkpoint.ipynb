# %%
# %load_ext ipython_sparql_pandas
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper('http://DESKTOP-CELL0BF:7200/repositories/20qsmall')
sparql.setReturnFormat(JSON)

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
import re
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i]= 1/len(popEntities)
    return Distribution


def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    #print(listOfObj[0])
    return(listOfObj,listOfPred)

def generateQuestion(listOfPred, listOfObj, index):
    flag = True
    if ('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>') in AttrHistory:
        return generateQuestion(listOfPred, listOfObj, index+1)
        
    else:
        AttrHistory.append('<' + str(listOfPred[index]['value']) +'> <'+str(listOfObj[index]['value'])+ '>')
    userAnswer = input(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    try:
        int(listOfObj[index]['value'])
    except ValueError:
           flag = False
            
    if userAnswer.startswith('y'):
        PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.') 
        """if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
              """ 
        
    elif userAnswer.startswith('n'):
        NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}') 
        """if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
              """
        
    else:
        return generateQuestion(listOfPred, listOfObj, index+1)
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)


  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            group by ?p ?o 
            ORDER BY ABS( {left/2} - ?count )
            """) 
        
    return FilterQuestion

# %%
def numberleft(PosFilters,NegFilters):
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}{NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))
    
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}
            {NegFilters} 
            }}
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    results = []
    for r in qres["results"]["bindings"]:
        results.append(r["s"]["value"])
    return results

# %%
# resets are variables
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    left = numberleft(PosFilters,NegFilters)
    FilterQuestion = updateQuery(left, PosFilters, NegFilters)
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i] = 1
        #Distribution[i]= 1/len(popEntities)
    return Distribution
    

def findPosAndNeg(listOfObj, listOfPred, index):
    Filter = '?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>.'
    negFilter='FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>. }}'
    EntitiesPositive = popentities(Filter, "")
    EntitiesNegative = popentities("", negFilter)
    return (EntitiesPositive, EntitiesNegative)
    

def generateQuestion(listOfObj, listOfPred, index, Distribution):

    AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
    userAnswer = input(f'Does the thing you are looking for have the attribute: {listOfPred[index]} {listOfObj[index]}?' )
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    if userAnswer.startswith('y'):
        for y in Yes:
            Distribution[y] = Distribution[y] * ( 1.0001 - ( len(Yes) / (len(Yes)+len(No))))
        for n in No:
            Distribution[n] = Distribution[n] * ( len(Yes) / (len(Yes)+len(No)) + .0001)
            
    elif userAnswer.startswith('n'):
        for y in Yes:
            Distribution[y] = Distribution[y] * len(Yes) / (len(Yes)+len(No) + .0001)
        for n in No:
            Distribution[n] = Distribution[n] * ( 1.0001 - ( len(Yes) / (len(Yes)+len(No)))) #small value for avoiding *0
    
    return Distribution
                       
def findSplits():
    possibleObj=[]
    possiblePred =[]
    count = []
    query =  f"""
            select (count(?s) as ?count)   ?o ?p
            {{               
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
        # ?s ?p ?o.
            }}
        group by  ?o ?p
        ORDER BY desc ( ?count )
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        possibleObj.append(r["o"]["value"])
        possiblePred.append(r["p"]["value"])
        count.append(r["count"]["value"])
   
    return (possibleObj, possiblePred, count)

def determineBestSplit(possibleObj, possiblePred, count):
    bestSplit=-1
    indexBestSplit = -1
    for i in range(45): 
        score=0
        #Fix The nummerical thing here::: (skip over i if nummer)
        if str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>') in AttrHistory:
            continue
        else:
            """ Yes, No = findPosAndNeg(possibleObj, possiblePred, i)
            OccurenceYes=len(Yes)
            OccurenceNo=len(No)
            TotalEntities = OccurenceYes+ OccurenceNo"""
            TotalEntities=numberleft("","")
            OccurencesYes=count[i]
            OccurencesNo
            ProbabilityYes=OccurenceYes/TotalEntities
            ProbabilityNo=OccurenceNo/TotalEntities
            Entropy = - (ProbabilityYes * math.log(ProbabilityYes+0.0001,2) + ProbabilityNo * math.log(ProbabilityNo+0.0001,2))
            #print(str(possiblePred[i]) +'> <'+str(possibleObj[i]), Entropy)
            if Entropy > bestSplit:
                bestSplit=Entropy
                indexBestSplit=i
                
            """for ent in EntitiesWithAttr:
                score += int(Distribution.get(ent))
            if score > bestSplit:
                bestSplit = score
                indexBestSplit = i"""
    return(indexBestSplit)

        
                             
"""preparePops
enter loop
find splits, determine best split, generate question (update probabilities)"""
# Out:
# 'preparePops\nenter loop\nfind splits, determine best split, generate question (update probabilities)'

# %%
import random
from random import * 
i=0
left, qres, PosAttr, NegAttr, AttrHistory = game_reset()
outofguess=[]
popularEntities =  popentities("\n".join(PosAttr),"")
Distribution = prepareProps(popularEntities)
while i<5:
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    if left <=1:
        break
    print('Question: %s' %(i+1))
    
    possibleObj, possiblePred, count = findSplits()
    indexSplit=determineBestSplit(possibleObj, possiblePred, count)
    Distribution = generateQuestion(possibleObj, possiblePred, indexSplit, Distribution)
  
    i+=1
    


if i == 5:
    highProb=-1
    for j in Distribution.values():
        print(j)
        if j > highProb:
            highProb=j
    answer = list(Distribution.keys())[list(Distribution.values()).index(j)]
    print("The Answer is: ", answer, "With a Probability of: ", highProb)
else:
    print('Final Question:')
    outofguess=popentities(PosFilters, NegFilters)
    guess = random.choice(outofguess)
    print(guess)
    answer = (input('Is this correct?').startswith('y'))
    if answer is True:
        print('Win')
    else:
        print('game over')
# Out:
# Question: 1
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human -0.0001442622910945383
# http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language 0.5484907128643688
# http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States 0.8881782852457413
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Actor 0.9835820657262164
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer 0.9581740757577992
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter 0.8498206858869118
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director 0.7927605054434934
# http://schema.org/memberOf> <http://yago-knowledge.org/resource/Democratic_Party_(United_States) 0.7532840655155275
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor 0.6939462501235468
# http://schema.org/nationality> <http://yago-knowledge.org/resource/United_Kingdom 0.6261075072713995
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Singer-songwriter 0.6261075072713995
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Politician 0.6261075072713995
# http://schema.org/homeLocation> <http://yago-knowledge.org/resource/Los_Angeles 0.588621765823454
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Songwriter 0.5689018667333502
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Writer 0.5273538556562811
# http://schema.org/memberOf> <http://yago-knowledge.org/resource/American_Academy_of_Arts_and_Sciences 0.5054524197366358
# http://schema.org/award> <http://yago-knowledge.org/resource/Presidential_Medal_of_Freedom 0.48274221819112617
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Guitarist 0.43468502947954
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Businessperson 0.43468502947954
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Statesman 0.43468502947954
# http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/German_language 0.43468502947954
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Pianist 0.38266923763312544
# http://schema.org/award> <http://yago-knowledge.org/resource/Grammy_Lifetime_Achievement_Award 0.354962254567512
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Dancer 0.354962254567512
# http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/French_language 0.354962254567512
# http://schema.org/memberOf> <http://yago-knowledge.org/resource/Republican_Party_(United_States) 0.3259704039832016
# http://schema.org/award> <http://yago-knowledge.org/resource/Theatre_World_Award 0.3259704039832016
# http://schema.org/award> <http://yago-knowledge.org/resource/Time_Person_of_the_Year 0.3259704039832016
# http://schema.org/homeLocation> <http://yago-knowledge.org/resource/New_York_City 0.3259704039832016
# http://schema.org/award> <http://yago-knowledge.org/resource/Rock_and_Roll_Hall_of_Fame 0.2955437844746489
# http://schema.org/award> <http://yago-knowledge.org/resource/Order_of_the_British_Empire 0.2955437844746489
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Executive_producer 0.2955437844746489
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Character_actor 0.2955437844746489
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Poet 0.2955437844746489
# http://schema.org/award> <http://yago-knowledge.org/resource/Academy_Award_for_Best_Actress 0.2955437844746489
# http://schema.org/alumniOf> <http://yago-knowledge.org/resource/Lee_Strasberg_Theatre_and_Film_Institute 0.2955437844746489
# http://schema.org/award> <http://yago-knowledge.org/resource/Kennedy_Center_Honors 0.2955437844746489
# http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/Spanish_language 0.2634890660985265
# http://schema.org/nationality> <http://yago-knowledge.org/resource/Canada 0.2634890660985265
# http://schema.org/birthPlace> <http://yago-knowledge.org/resource/Los_Angeles 0.2634890660985265
# http://schema.org/award> <http://yago-knowledge.org/resource/Order_of_the_Elephant 0.2634890660985265
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Restaurateur 0.22954744576904407
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Lyricist 0.22954744576904407
# http://schema.org/givenName> <http://yago-knowledge.org/resource/George_(given_name) 0.22954744576904407
# Does the thing you are looking for have the attribute: http://schema.org/hasOccupation http://yago-knowledge.org/resource/Actor? yes
# Question: 2
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human -0.0001442622910945383
# http://schema.org/knowsLanguage> <http://yago-knowledge.org/resource/English_language 0.5484907128643688
# http://schema.org/nationality> <http://yago-knowledge.org/resource/United_States 0.8881782852457413
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_producer 0.9581740757577992
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Screenwriter 0.8498206858869118
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Film_director 0.7927605054434934
# http://schema.org/memberOf> <http://yago-knowledge.org/resource/Democratic_Party_(United_States) 0.7532840655155275
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Stage_actor 0.6939462501235468
# http://schema.org/nationality> <http://yago-knowledge.org/resource/United_Kingdom 0.6261075072713995
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Singer-songwriter 0.6261075072713995
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/Politician 0.6261075072713995
# http://schema.org/homeLocation> <http://yago-knowledge.org/resource/Los_Angeles 0.588621765823454
# http://schema.org/hasOccupation> <http://yago-knowledge.org/resource/
# 0.010022195650122854
# 0.042746400786053004
# 0.10084064584938987
# 0.010022195650122854
# 0.008574849753834211
# 0.004419194643747553
# 0.0032715515988365235
# 0.010022195650122854
# 0.0032715515988365235
# 0.004419194643747553
# 0.010022195650122854
# 0.0032715515988365235
# 0.004419194643747553
# 0.010425075183290429
# 0.0074194808887637
# 0.004419194643747553
# 0.005323750651688692
# 0.010022195650122854
# 0.0074194808887637
# 0.0074194808887637
# 0.04446475179360572
# 0.05196994172526509
# 0.0032715515988365235
# 0.016964580604714875
# 0.004419194643747553
# 0.01395373436302895
# 0.04446475179360572
# 0.005323750651688692
# 0.010022195650122854
# 0.004419194643747553
# 0.0032715515988365235
# 0.0032715515988365235
# 0.010022195650122854
# 0.0032715515988365235
# 0.010022195650122854
# 0.0074194808887637
# 0.010022195650122854
# 0.010022195650122854
# 0.01395373436302895
# 0.004419194643747553
# 0.0032715515988365235
# 0.010022195650122854
# 0.010022195650122854
# 0.010022195650122854
# 0.01158286181900984
# 0.004419194643747553
# 0.004419194643747553
# 0.0032715515988365235
# 0.010022195650122854
# 0.004419194643747553
# 0.007191294299914789
# 0.01158286181900984
# 0.004419194643747553
# 0.03847360427612894
# 0.010022195650122854
# 0.031645371410372145
# 0.010022195650122854
# 0.004419194643747553
# The Answer is:  http://yago-knowledge.org/resource/George_W._Bush With a Probability of:  0.10084064584938987

# %%
def generateBotQuestion(listOfObj, listOfPred, index, subject, Distribution):
    
    AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
    print(f'Does the thing you are looking for have the attribute: {listOfPred[index].split("/")[-1]} {listOfObj[index].split("/")[-1]}?' )
    answer = findAnswer(subject, '<' + str(listOfPred[index]) +'>', '<'+str(listOfObj[index])+ '>')
    print(answer)
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    OccurenceYes=len(Yes)
    OccurenceNo=len(No)
    NEntities=OccurenceYes+OccurenceNo
    ProbabilityYes=OccurenceYes/NEntities
    ProbabilityNo=OccurenceNo/NEntities
    if answer:   
        for y in Yes:
            Distribution[y] +=1 
        for n in No:
            Distribution[n] -=1
            
    else:
        for y in Yes:
            Distribution[y] -=1
        for n in No:
            Distribution[n]+=1
            
    print(Distribution[subject[1:-1]])
    return Distribution


def pickSubject():
    ind=randint(0,134)
    query = f"""
    select distinct ?s
    where {{
        # ?s ?p ?o .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
    }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"][ind:ind+1]:
        return("<"+r["s"]["value"]+">")

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
#without printing results
from random import randint
import random
import math

wincount = 0
gamesplayed = 0
totalgames = 100

while gamesplayed < totalgames:
    left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
    # Resets all variables
    i=0
    outofguess = []
    # pick subject
    subject = pickSubject()
    print("\n" , subject)
    popularEntities =  popentities("\n".join(PosAttr),"")
    Distribution = prepareProps(popularEntities)
    
    while i < 20:

        # list of Pred and Obj for questions
        listOfObj ,listOfPred = extractCountAndAttr(qres)

        # if only 1 popular entity is left break


        # ask question and add filters to query
        print('Question: %s' %(i+1))
        possibleObj, possiblePred, count = findSplits()
        indexSplit=determineBestSplit(possibleObj, possiblePred, count)
        Distribution = generateBotQuestion(possibleObj, possiblePred, indexSplit,subject, Distribution)
        i+=1

    # Prints answer
    #print(Distribution)
    highProb=-1
    for j in Distribution.values():

        if j > highProb:
            highProb=j
    answer = list(Distribution.keys())[list(Distribution.values()).index(highProb)]
    print("The Answer is: ", answer, "With a Probability of: ", highProb)
    print(subject)
    if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
        wincount +=1
    gamesplayed+=1
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
#  <http://yago-knowledge.org/resource/Eminem>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# True
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Eminem With a Probability of:  21
# <http://yago-knowledge.org/resource/Eminem>
#
#  <http://yago-knowledge.org/resource/Nelson_Mandela>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# True
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# True
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Nelson_Mandela With a Probability of:  21
# <http://yago-knowledge.org/resource/Nelson_Mandela>
#
#  <http://yago-knowledge.org/resource/Chris_Evans_(actor)>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# True
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Chris_Evans_(actor) With a Probability of:  21
# <http://yago-knowledge.org/resource/Chris_Evans_(actor)>
#
#  <http://yago-knowledge.org/resource/Paul_Walker>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Paul_Walker With a Probability of:  21
# <http://yago-knowledge.org/resource/Paul_Walker>
#
#  <http://yago-knowledge.org/resource/Queen_Victoria>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Priyanka_Chopra With a Probability of:  21
# <http://yago-knowledge.org/resource/Queen_Victoria>
#
#  <http://yago-knowledge.org/resource/Matthew_McConaughey>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Paul_Walker With a Probability of:  21
# <http://yago-knowledge.org/resource/Matthew_McConaughey>
#
#  <http://yago-knowledge.org/resource/William_Shakespeare>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Priyanka_Chopra With a Probability of:  21
# <http://yago-knowledge.org/resource/William_Shakespeare>
#
#  <http://yago-knowledge.org/resource/Tobey_Maguire>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 21
# The Answer is:  http://yago-knowledge.org/resource/Tobey_Maguire With a Probability of:  21
# <http://yago-knowledge.org/resource/Tobey_Maguire>
#
#  <http://yago-knowledge.org/resource/Bill_Clinton>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 11
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 12
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 13
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 14
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 15
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# True
# 16
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# True
# 17
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 18
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 19
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# True
# 20
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# True
# 21
# The Answer is:  http://yago-knowledge.org/resource/Bill_Clinton With a Probability of:  21
# <http://yago-knowledge.org/resource/Bill_Clinton>
#
#  <http://yago-knowledge.org/resource/Kristen_Stewart>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 2
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 3
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 4
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 5
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 6
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 7
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 8
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 9
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 10
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 11
# Question: 11
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#
# G:\conda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# G:\conda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# G:\conda\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# G:\conda\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# G:\conda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# G:\conda\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 500:
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-21-fd6cb6f4f168> in <module>
#      29         # ask question and add filters to query
#      30         print('Question: %s' %(i+1))
# ---> 31         possibleObj, possiblePred, count = findSplits()
#      32         indexSplit=determineBestSplit(possibleObj, possiblePred, count)
#      33         Distribution = generateBotQuestion(possibleObj, possiblePred, indexSplit,subject, Distribution)
#
# <ipython-input-20-dacd5abe42ba> in findSplits()
#      50     sparql.setQuery(query)
#      51     sparql.setReturnFormat(JSON)
# ---> 52     qres = sparql.query().convert()
#      53     for r in qres["results"]["bindings"]:
#      54         possibleObj.append(r["o"]["value"])
#
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1083                 raise URITooLong(e.read())
#    1084             elif e.code == 500:
# -> 1085                 raise EndPointInternalError(e.read())
#    1086             else:
#    1087                 raise e
#
# EndPointInternalError: EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Query evaluation error: Insufficient free Heap Memory 245Mb for group by and distinct, threshold:250Mb, reached 0Mb (HTTP status 500)\r\n'

# %%
gamesplayed
# Out:
# 9

# %%
sum(Distribution.values())
# Out:
# 1.0050407038384892

# %%
print(subject[1:-1])
# Out:
# http://yago-knowledge.org/resource/Tina_Turner

# %%
print(numberleft("",""))
# Out:
# 134

# %%
NegFilters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-fce8c2121027> in <module>
# ----> 1 NegFilters
#
# NameError: name 'NegFilters' is not defined
