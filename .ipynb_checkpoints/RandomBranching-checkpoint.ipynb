# %%
# %load_ext ipython_sparql_pandas
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper('http://DESKTOP-CELL0BF:7200/repositories/20qsmall')
sparql.setReturnFormat(JSON)
# Out:
# The ipython_sparql_pandas extension is already loaded. To reload it, use:
#   %reload_ext ipython_sparql_pandas

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
import re
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i]= 1/len(popEntities)
    return Distribution


def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    #print(listOfObj[0])
    return(listOfObj,listOfPred)

def generateQuestion(listOfPred, listOfObj, index):
    flag = True
    if ('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>') in AttrHistory:
        return generateQuestion(listOfPred, listOfObj, index+1)
        
    else:
        AttrHistory.append('<' + str(listOfPred[index]['value']) +'> <'+str(listOfObj[index]['value'])+ '>')
    userAnswer = input(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    try:
        int(listOfObj[index]['value'])
    except ValueError:
           flag = False
            
    if userAnswer.startswith('y'):
        PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.') 
        """if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
              """ 
        
    elif userAnswer.startswith('n'):
        NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}') 
        """if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
              """
        
    else:
        return generateQuestion(listOfPred, listOfObj, index+1)
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)


  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            group by ?p ?o 
            ORDER BY ABS( {left/2} - ?count )
            """) 
        
    return FilterQuestion

# %%
def numberleft(PosFilters,NegFilters):
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}            
            {NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))
    
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}
            {NegFilters} 
            }}
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    results = []
    for r in qres["results"]["bindings"]:
        results.append(r["s"]["value"])
    return results

# %%
# resets are variables
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    left = numberleft(PosFilters,NegFilters)
    FilterQuestion = updateQuery(left, PosFilters, NegFilters)
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i]= 1/len(popEntities)
    return Distribution
    

def findPosAndNeg(listOfObj, listOfPred, index):
    Filter = '?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>.'
    negFilter='FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>. }}'
    EntitiesPositive = popentities(Filter, "")
    EntitiesNegative = popentities("", negFilter)
    return (EntitiesPositive, EntitiesNegative)
    

def generateQuestion(listOfObj, listOfPred, index, Distribution):

    AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
    userAnswer = input(f'Does the thing you are looking for have the attribute: {listOfPred[index]} {listOfObj[index]}?' )
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    if userAnswer.startswith('y'):
        for y in Yes:
            Distribution[y] = Distribution[y] * ( 1.0001 - ( len(Yes) / (len(Yes)+len(No))))
        for n in No:
            Distribution[n] = Distribution[n] * ( len(Yes) / (len(Yes)+len(No)) + .0001)
            
    elif userAnswer.startswith('n'):
        for y in Yes:
            Distribution[y] = Distribution[y] * len(Yes) / (len(Yes)+len(No) + .0001)
        for n in No:
            Distribution[n] = Distribution[n] * ( 1.0001 - ( len(Yes) / (len(Yes)+len(No)))) #small value for avoiding *0
    
    return Distribution
                       
def findSplits():
    possibleObj=[]
    possiblePred =[]
    count = []
    query =  f"""
            select (count(?s) as ?count)   ?o ?p
            {{               
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
        # ?s ?p ?o.
            }}
        group by  ?o ?p
        ORDER BY desc ( ?count )
        Limit 150
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        possibleObj.append(r["o"]["value"])
        possiblePred.append(r["p"]["value"])
        count.append(r["count"]["value"])
   
    return (possibleObj, possiblePred, count)
  


def determineBestSplit(possibleObj, possiblePred, count):
    bestSplit=1
    indexBestSplit = -1
    randomBranching=[]
    for j in range(50):
        randomBranching.append(min(randint(2,100), randint(2,100))) #Randomly Search for attributes
    for i in randomBranching: 
        score=0
        #Fix The nummerical thing here::: (skip over i if nummer)
        if str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>') in AttrHistory:
            continue
        else:
            Yes, No = findPosAndNeg(possibleObj, possiblePred, i)
            OccurenceYes=len(Yes)
            OccurenceNo=len(No)
            TotalEntities = OccurenceYes+ OccurenceNo
            FactorYes = 1
            FactorNo = 1            
            
            #removeUnderTreshholdEntities(Yes, No)
            #EphaziseHighProbabilities(Yes, No)
            ProbabilityYes=OccurenceYes/TotalEntities
            ProbabilityNo=OccurenceNo/TotalEntities
            Entropy = -( (ProbabilityYes * math.log(ProbabilityYes,2)*FactorYes) + (ProbabilityNo * math.log(ProbabilityNo,2))*FactorNo     )
            if Entropy < bestSplit:
                bestSplit=Entropy
                indexBestSplit=i
        return indexBestSplit
                
                
"""def determineBestSplit(possibleObj, possiblePred, count):
    bestSplit=-1
    indexBestSplit = -1
    for i in range(45): 
        score=0
        #Fix The nummerical thing here::: (skip over i if nummer)
        if str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>') in AttrHistory:
            continue
        else:
            Filter = '?s <' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>.'
            negFilter='FILTER NOT EXISTS {{ \n ?s <' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>. }}'
            EntitiesWithAttr = popentities(Filter, "")
            EntitiesWithoutAttr = popentities("", negFilter)
            for ent in EntitiesWithAttr:
                score += int(Distribution.get(ent))
            if score > bestSplit:
                bestSplit = score
                indexBestSplit = i
    return(indexBestSplit)"""

        
                             
"""preparePops
enter loop
find splits, determine best split, generate question (update probabilities)"""
# Out:
# 'preparePops\nenter loop\nfind splits, determine best split, generate question (update probabilities)'

# %%
import random
from random import * 

i=0
totalPopEnts = left
left, qres, PosAttr, NegAttr, AttrHistory = game_reset()
outofguess=[]
popularEntities =  popentities("\n".join(PosAttr),"")
Distribution = prepareProps(popularEntities)
while i<5:
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    if left <=1:
        break
    print('Question: %s' %(i+1))
    
    possibleObj, possiblePred, count = findSplits()
    indexSplit=determineBestSplit(possibleObj, possiblePred, count)
    Distribution = generateQuestion(possibleObj, possiblePred, indexSplit, Distribution)
  
    i+=1
    


if i == 5:
    highProb=-1
    for j in Distribution.values():
        print(j)
        if j > highProb:
            highProb=j
    answer = list(Distribution.keys())[list(Distribution.values()).index(j)]
    print("The Answer is: ", answer, "With a Probability of: ", highProb)
else:
    print('Final Question:')
    outofguess=popentities(PosFilters, NegFilters)
    guess = random.choice(outofguess)
    print(guess)
    answer = (input('Is this correct?').startswith('y'))
    if answer is True:
        print('Win')
    else:
        print('game over')
# Out:
# Question: 1
# Does the thing you are looking for have the attribute: http://schema.org/award http://yago-knowledge.org/resource/Congressional_Gold_Medal? y
# Question: 2
# Does the thing you are looking for have the attribute: http://schema.org/award http://yago-knowledge.org/resource/Grammy_Lifetime_Achievement_Award? y
# Question: 3
# Does the thing you are looking for have the attribute: http://schema.org/hasOccupation http://yago-knowledge.org/resource/Poet? y
# Question: 4
# Does the thing you are looking for have the attribute: http://schema.org/award http://yago-knowledge.org/resource/Grammy_Award_for_Best_Rap%2FSung_Performance? y
# Question: 5
# Does the thing you are looking for have the attribute: http://schema.org/hasOccupation http://yago-knowledge.org/resource/Executive_producer? y
# 2.1371243752962843e-08
# 4.991574357955758e-08
# 4.991574357955758e-08
# 2.7905050215109893e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 4.991574357955758e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109897e-08
# 2.7905050215109893e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 3.9651930808303386e-08
# 3.9651930808303386e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109893e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 3.8703543663452405e-07
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 5.499614670280643e-07
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109897e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.1371243752962843e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109897e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.1371243752962843e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109893e-08
# 1.5408553678482092e-09
# 3.8703543663452405e-07
# 2.7905050215109893e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109897e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.1371243752962843e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 4.991574357955758e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109893e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 3.9651930808303386e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 3.9651930808303386e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 2.7905050215109893e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# 3.8703543663452405e-07
# 1.5408553678482092e-09
# 2.1371243752962843e-08
# 1.5408553678482092e-09
# 1.5408553678482092e-09
# The Answer is:  http://yago-knowledge.org/resource/George_W._Bush With a Probability of:  5.499614670280643e-07

# %%
def generateBotQuestion(listOfObj, listOfPred, index, subject, Distribution):
    
    AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
    print(f'Does the thing you are looking for have the attribute: {listOfPred[index].split("/")[-1]} {listOfObj[index].split("/")[-1]}?' )
    answer = findAnswer(subject, '<' + str(listOfPred[index]) +'>', '<'+str(listOfObj[index])+ '>')
    #print(answer)
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    OccurenceYes=len(Yes)
    OccurenceNo=len(No)
    NEntities=OccurenceYes+OccurenceNo
    ProbabilityYes=OccurenceYes/NEntities
    ProbabilityNo=OccurenceNo/NEntities
    reward=1/len(Yes)
    punish=1/len(No)
    if answer:   
        for y in Yes:
            Distribution[y] = Distribution[y] + reward
        for n in No:
            Distribution[n] = Distribution[n] - punish
            
    else:
        for y in Yes:
            Distribution[y] = Distribution[y] -punish
        for n in No:
            Distribution[n] = Distribution[n] +reward
                               
                               
    """if answer:   
        for y in Yes:
            Distribution[y] = Distribution[y] * (0.9 / ProbabilityYes)
        for n in No:
            Distribution[n] = (Distribution[n] * (0.1 / ProbabilityNo)
            
    else:
        for y in Yes:
            Distribution[y] = Distribution[y] * ( 0.1 / ProbabilityYes)
        for n in No:
            Distribution[n] = (Distribution[n] *( 0.9 / ProbabilityNo)"""
            
        
    print(Distribution[subject[1:-1]])
    return Distribution


def pickSubject():
    ind=randint(0,134)
    query = f"""
    select distinct ?s
    where {{
        # ?s ?p ?o .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
    }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"][ind:ind+1]:
        return("<"+r["s"]["value"]+">")

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
#without printing results
from random import randint
import random
import math

wincount = 0
gamesplayed = 0
totalgames = 100

while gamesplayed < totalgames:
    left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
    possibleObj, possiblePred, count = findSplits()
    # Resets all variables
    i=0
    outofguess = []
    # pick subject
    subject = pickSubject()
    print("\n" , subject)
    popularEntities =  popentities("\n".join(PosAttr),"")
    Distribution = prepareProps(popularEntities)
    
    while i < 20:

        # list of Pred and Obj for questions
        listOfObj ,listOfPred = extractCountAndAttr(qres)

        # if only 1 popular entity is left break


        # ask question and add filters to query
        print('Question: %s' %(i+1))
        indexSplit=determineBestSplit(possibleObj, possiblePred, count)
        Distribution = generateBotQuestion(possibleObj, possiblePred, indexSplit,subject, Distribution)
        i+=1

    # Prints answer
    #print(Distribution)
    highProb=-1
    for j in Distribution.values():

        if j > highProb:
            highProb=j
    answer = list(Distribution.keys())[list(Distribution.values()).index(highProb)]
    print("The Answer is: ", answer, "With a Probability of: ", highProb)
    print(subject, Distribution[subject[1:-1]])
    if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
        wincount +=1
    gamesplayed+=1
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
#  <http://yago-knowledge.org/resource/Kim_Kardashian>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# 0.0907960199004975
# Question: 2
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# 0.20190713101160862
# Question: 3
# Does the thing you are looking for have the attribute: award Ellis_Island_Medal_of_Honor?
# 0.4519071310116086
# Question: 4
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# 0.5630182421227197
# Question: 5
# Does the thing you are looking for have the attribute: givenName John_(given_name)?
# 0.8130182421227197
# Question: 6
# Does the thing you are looking for have the attribute: memberOf American_Legion?
# 1.0630182421227197
# Question: 7
# Does the thing you are looking for have the attribute: award Doublespeak_Award?
# 1.3130182421227197
# Question: 8
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Actor_–_Motion_Picture_Drama?
# 1.5630182421227197
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Restaurateur?
# 1.7630182421227196
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Child_actor?
# 2.01301824212272
# Question: 11
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Supporting_Actor?
# 2.26301824212272
# Question: 12
# Does the thing you are looking for have the attribute: award Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture?
# 2.51301824212272
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# 2.624129353233831
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# 2.651156380260858
# Question: 15
# Does the thing you are looking for have the attribute: award L'Équipe_Champion_of_Champions?
# 2.901156380260858
# Question: 16
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Supporting_Actress_–_Motion_Picture?
# 3.151156380260858
# Question: 17
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# 3.2344897135941917
# Question: 18
# Does the thing you are looking for have the attribute: memberOf American_Philosophical_Society?
# 3.4844897135941917
# Question: 19
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# 3.651156380260858
# Question: 20
# Does the thing you are looking for have the attribute: award Kennedy_Center_Honors?
# 3.794013523118001
# The Answer is:  http://yago-knowledge.org/resource/Jake_Gyllenhaal With a Probability of:  3.794013523118001
# <http://yago-knowledge.org/resource/Kim_Kardashian> 3.794013523118001
#
#  <http://yago-knowledge.org/resource/Aaliyah>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# 0.016009695114172728
# Question: 2
# Does the thing you are looking for have the attribute: award MTV_Movie_Award_for_Best_Kiss?
# 0.2660096951141727
# Question: 3
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_Rap%2FSung_Performance?
# 0.5160096951141727
# Question: 4
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# 0.6826763617808393
# Question: 5
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# 0.7937874728919505
# Question: 6
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# 0.9366446157490933
# Question: 7
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_Dance_Recording?
# 1.2699779490824266
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# 1.3175969967014742
# Question: 9
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# 1.4425969967014742
# Question: 10
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# 1.4952285756488426
# Question: 11
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# 1.5297113342695323
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# 1.5567383612965593
# Question: 13
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# 1.623405027963226
# Question: 14
# Does the thing you are looking for have the attribute: award L'Équipe_Champion_of_Champions?
# 1.873405027963226
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
#
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# 1.1900023691068466
# Question: 9
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# 1.261430940535418
# Question: 10
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Supporting_Actor?
# 1.511430940535418
# Question: 11
# Does the thing you are looking for have the attribute: memberOf American_Philosophical_Society?
# 1.761430940535418
# Question: 12
# Does the thing you are looking for have the attribute: knowsLanguage Spanish_language?
# 1.9280976072020848
# Question: 13
# Does the thing you are looking for have the attribute: award Kennedy_Center_Honors?
# 2.0709547500592276
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# 2.2138118929163704
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Restaurateur?
# 2.4138118929163705
# Question: 16
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Supporting_Actress_–_Motion_Picture?
# 2.6638118929163705
# Question: 17
# Does the thing you are looking for have the attribute: nationality United_States?
# 2.6745645810884136
# Question: 18
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# 2.722183628707461
# Question: 19
# Does the thing you are looking for have the attribute: givenName John_(given_name)?
# 2.972183628707461
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# 3.115040771564604
# The Answer is:  http://yago-knowledge.org/resource/Eminem With a Probability of:  3.115040771564604
# <http://yago-knowledge.org/resource/Blake_Lively> 3.115040771564604
#
#  <http://yago-knowledge.org/resource/Novak_Djokovic>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Restaurateur?
# 0.20746268656716418
# Question: 2
# Does the thing you are looking for have the attribute: award Doublespeak_Award?
# 0.45746268656716416
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# 0.5824626865671642
# Question: 4
# Does the thing you are looking for have the attribute: award Grammy_Hall_of_Fame?
# 0.9157960199004975
# Question: 5
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_Rap%2FSung_Performance?
# 1.1657960199004975
# Question: 6
# Does the thing you are looking for have the attribute: givenName John_(given_name)?
# 1.4157960199004975
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# 1.5586531627576403
# Question: 8
# Does the thing you are looking for have the attribute: memberOf American_Legion?
# 1.8086531627576403
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Child_actor?
# 2.0586531627576403
# Question: 10
# Does the thing you are looking for have the attribute: nationality Canada?
# 2.225319829424307
# Question: 11
# Does the thing you are looking for have the attribute: award NBA_Most_Valuable_Player_Award?
# 2.475319829424307
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# 2.48830684241132
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# 2.6311639852684627
# Question: 14
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# 2.7561639852684627
# Question: 15
# Does the thing you are looking for have the attribute: award BAFTA_Award_for_Best_Actress_in_a_Leading_Role?
# 3.0061639852684627
# Question: 16
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Original_Song?
# 3.339497318601796
# Question: 17
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# 3.3871163662208437
# Question: 18
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Supporting_Actress_–_Motion_Picture?
# 3.6371163662208437
# Question: 19
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# 3.7799735090779865
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# 3.835529064633542
# The Answer is:  http://yago-knowledge.org/resource/Barack_Obama With a Probability of:  3.835529064633542
# <http://yago-knowledge.org/resource/Novak_Djokovic> 3.835529064633542
#
#  <http://yago-knowledge.org/resource/Abraham_Lincoln>
# Question: 1
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# 0.15031982942430702
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# 0.19793887704335464
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# 0.34079601990049746
# Question: 4
# Does the thing you are looking for have the attribute: givenName John_(given_name)?
# 0.5907960199004975
# Question: 5
# Does the thing you are looking for have the attribute: award MTV_Movie_Award_for_Best_Kiss?
# 0.8407960199004975
# Question: 6
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# 1.007462686567164
# Question: 7
# Does the thing you are looking for have the attribute: award NBA_Most_Valuable_Player_Award?
# 1.257462686567164
# Question: 8
# Does the thing you are looking for have the attribute: award Golden_Globe_Cecil_B._DeMille_Award?
# 1.507462686567164
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Child_actor?
# 1.757462686567164
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# 1.9003198294243069
# Question: 11
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# 1.9348025880449966
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# 2.01813592137833
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# 2.160993064235473
# Question: 14
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# 2.2086121118545203
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# 2.2711121118545203
# Question: 16
# Does the thing you are looking for have the attribute: award MTV_Video_Music_Award_for_Best_Female_Video?
# 2.4711121118545205
# Question: 17
# Does the thing you are looking for have the attribute: homeLocation Detroit?
# 2.804445445187854
# Question: 18
# Does the thing you are looking for have the attribute: award Order_of_the_British_Empire?
# 2.947302588044997
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# 2.9949216356640442
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# 3.1060327467751554
# The Answer is:  http://yago-knowledge.org/resource/George_W._Bush With a Probability of:  3.1060327467751554
# <http://yago-knowledge.org/resource/Abraham_Lincoln> 3.1060327467751554
#
#  <http://yago-knowledge.org/resource/Kanye_West>
# Question: 1
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Supporting_Actress_–_Motion_Picture?
# 0.2574626865671642
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Lyricist?
# 0.4574626865671642
# Question: 3
# Does the thing you are looking for have the attribute: award NBA_Most_Valuable_Player_Award?
# 0.7074626865671643
# Question: 4
# Does the thing you are looking for have the attribute: award Congressional_Gold_Medal?
# 0.9074626865671642
# Question: 5
# Does the thing you are looking for have the attribute: award Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture?
# 1.1574626865671642
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# 1.2574626865671643
# Question: 7
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# 1.3407960199004976
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# 1.4836531627576404
# Question: 9
# Does the thing you are looking for have the attribute: homeLocation Detroit?
# 1.8169864960909736
# Question: 10
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# 1.9280976072020848
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# 1.9836531627576404
# Question: 12
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# 2.1086531627576406
# Question: 13
# Does the thing you are looking for have the attribute: memberOf American_Legion?
# 2.3586531627576406
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# 2.5015103056147834
# Question: 15
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# 2.644367448471926
# Question: 16
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# 2.6969990274192948
# Question: 17
# Does the thing you are looking for have the attribute: award Kennedy_Center_Honors?
# 2.8398561702764376
# Question: 18
# Does the thing you are looking for have the attribute: nationality United_States?
# 2.8506088584484806
# Question: 19
# Does the thing you are looking for have the attribute: givenName George_(given_name)?
# 3.0506088584484807
# Question: 20
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# 3.161719969559592
# The Answer is:  http://yago-knowledge.org/resource/Kanye_West With a Probability of:  3.161719969559592
# <http://yago-knowledge.org/resource/Kanye_West> 3.161719969559592
#
#  None
# Question: 1
# Does the thing you are looking for have the attribute: award BAFTA_Award_for_Best_Actress_in_a_Leading_Role?
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#
# G:\conda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# G:\conda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# G:\conda\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# G:\conda\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# G:\conda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# G:\conda\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 400:
#
# During handling of the above exception, another exception occurred:
#
# QueryBadFormed                            Traceback (most recent call last)
# <ipython-input-81-a0445e24eea2> in <module>
#      31         print('Question: %s' %(i+1))
#      32         indexSplit=determineBestSplit(possibleObj, possiblePred, count)
# ---> 33         Distribution = generateBotQuestion(possibleObj, possiblePred, indexSplit,subject, Distribution)
#      34         i+=1
#      35
#
# <ipython-input-73-5592211ec4e5> in generateBotQuestion(listOfObj, listOfPred, index, subject, Distribution)
#       3     AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
#       4     print(f'Does the thing you are looking for have the attribute: {listOfPred[index].split("/")[-1]} {listOfObj[index].split("/")[-1]}?' )
# ----> 5     answer = findAnswer(subject, '<' + str(listOfPred[index]) +'>', '<'+str(listOfObj[index])+ '>')
#       6     #print(answer)
#       7     Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
#
# <ipython-input-73-5592211ec4e5> in findAnswer(subject, p, o)
#      71     sparql.setQuery(query)
#      72     sparql.setReturnFormat(JSON)
# ---> 73     qres = sparql.query().convert()
#      74     res = qres["results"]["bindings"]
#      75     return (len(res))>0
#
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1075         except urllib.error.HTTPError as e:
#    1076             if e.code == 400:
# -> 1077                 raise QueryBadFormed(e.read())
#    1078             elif e.code == 404:
#    1079                 raise EndPointNotFound(e.read())
#
# QueryBadFormed: QueryBadFormed: a bad request has been sent to the endpoint, probably the sparql query is bad formed.
#
# Response:
# b'MALFORMED QUERY: Lexical error at line 5, column 29.  Encountered: \'41\' (41), after prefix "None"'

# %%
# Out:
#   File "<ipython-input-26-04012505ba3d>", line 5
#     fam.get(i)=fam.get(i)-2
#     ^
# SyntaxError: cannot assign to function call

# %%
sum(Distribution.values())
# Out:
# 1.0050407038384892

# %%
print(subject[1:-1])
# Out:
# http://yago-knowledge.org/resource/Tina_Turner

# %%
gamesplayed
# Out:
# 38
