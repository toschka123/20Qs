# %%
# %load_ext ipython_sparql_pandas
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper('http://DESKTOP-CELL0BF:7200/repositories/20qsmall')
sparql.setReturnFormat(JSON)

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
import re
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i]= 1/len(popEntities)
    return Distribution


def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    #print(listOfObj[0])
    return(listOfObj,listOfPred)


  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            group by ?p ?o 
            ORDER BY ABS( {left/2} - ?count )
            """) 
        
    return FilterQuestion

# %%
def numberleft(PosFilters,NegFilters):
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}{NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))
    
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}
            {NegFilters} 
            }}
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    results = []
    for r in qres["results"]["bindings"]:
        results.append(r["s"]["value"])
    return results

# %%
# resets are variables
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    left = numberleft(PosFilters,NegFilters)
    FilterQuestion = updateQuery(left, PosFilters, NegFilters)
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i] = 1
        #Distribution[i]= 1/len(popEntities)
    return Distribution
    

def findPosAndNeg(listOfObj, listOfPred, index):
    Filter = '?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>.'
    negFilter='FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>. }}'
    EntitiesPositive = popentities(Filter, "")
    EntitiesNegative = popentities("", negFilter)
    return (EntitiesPositive, EntitiesNegative)
    
                       
def findSplits():
    possibleObj=[]
    possiblePred =[]
    count = []
    query =  f"""
            select (count(?s) as ?count)   ?o ?p
            {{               
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
        # ?s ?p ?o.
            }}
        group by  ?o ?p
        ORDER BY desc ( ?count )
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        possibleObj.append(r["o"]["value"])
        possiblePred.append(r["p"]["value"])
        count.append(r["count"]["value"])
   
    return (possibleObj, possiblePred, count)

def determineBestSplit(possibleObj, possiblePred, count):
    bestSplit=-1
    indexBestSplit = -1
    for i in range(45): 
        score=0
        #Fix The nummerical thing here::: (skip over i if nummer)
        if str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>') in AttrHistory:
            continue
        else:
            Yes, No = findPosAndNeg(possibleObj, possiblePred, i)
            OccurenceYes=len(Yes)
            OccurenceNo=len(No)
            WeightYes=0
            WeightNo=0
            for y in Yes:
                WeightYes+=Distribution[y]
            for n in No:
                WeightNo+=Distribution[n]
            SumWeights=WeightYes+WeightNo
            ProbabilityYes=WeightYes/SumWeights
            ProbabilityNo=WeightNo/SumWeights
            Entropy = - (ProbabilityYes * math.log(ProbabilityYes+0.0001,2) + ProbabilityNo * math.log(ProbabilityNo+0.0001,2))
            #print(str(possiblePred[i]) +'> <'+str(possibleObj[i]), Entropy)
            if Entropy > bestSplit:
                bestSplit=Entropy
                indexBestSplit=i
                
            """for ent in EntitiesWithAttr:
                score += int(Distribution.get(ent))
            if score > bestSplit:
                bestSplit = score
                indexBestSplit = i"""
    return(indexBestSplit)

        
                             
"""preparePops
enter loop
find splits, determine best split, generate question (update probabilities)"""
# Out:
# 'preparePops\nenter loop\nfind splits, determine best split, generate question (update probabilities)'

# %%
def generateBotQuestion(listOfObj, listOfPred, index, subject, Distribution):
    
    AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
    print(f'Does the thing you are looking for have the attribute: {listOfPred[index].split("/")[-1]} {listOfObj[index].split("/")[-1]}?' )
    answer = findAnswer(subject, '<' + str(listOfPred[index]) +'>', '<'+str(listOfObj[index])+ '>')
    print(answer)
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    OccurenceYes=len(Yes)
    OccurenceNo=len(No)
    NEntities=OccurenceYes+OccurenceNo
    ProbabilityYes=OccurenceYes/NEntities
    ProbabilityNo=OccurenceNo/NEntities
    if answer:   
        for y in Yes:
            Distribution[y]= Distribution[y]*0.99
        for n in No:
            Distribution[n]= Distribution[n]*0.01
            
    else:
        for y in Yes:
            Distribution[y] = Distribution[y]*0.01
        for n in No:
            Distribution[n] = Distribution[n]*0.99
            
    print(Distribution[subject[1:-1]])
    return Distribution

def pickSubject():
    ind=randint(0,134)
    query = f"""
    select distinct ?s
    where {{
        # ?s ?p ?o .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
    }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"][ind:ind+1]:
        return("<"+r["s"]["value"]+">")

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
#without printing results
from random import randint
import random
import math

wincount = 0
gamesplayed = 0
totalgames = 100

while gamesplayed < totalgames:
    left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
    possibleObj, possiblePred, count = findSplits()
    # Resets all variables
    i=0
    outofguess = []
    # pick subject
    subject = pickSubject()
    print("\n" , subject)
    popularEntities =  popentities("\n".join(PosAttr),"")
    Distribution = prepareProps(popularEntities)
    
    while i < 20:

        # list of Pred and Obj for questions
        listOfObj ,listOfPred = extractCountAndAttr(qres)

        # if only 1 popular entity is left break


        # ask question and add filters to query
        print('Question: %s' %(i+1))

        indexSplit=determineBestSplit(possibleObj, possiblePred, count)
        Distribution = generateBotQuestion(possibleObj, possiblePred, indexSplit,subject, Distribution)
        i+=1

    # Prints answer
    #print(Distribution)
    highProb=-1
    for j in Distribution.values():

        if j > highProb:
            highProb=j
    answer = list(Distribution.keys())[list(Distribution.values()).index(highProb)]
    print("The Answer is: ", answer, "With a Probability of: ", highProb)
    print(subject)
    if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
        wincount +=1
    gamesplayed+=1
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
#  <http://yago-knowledge.org/resource/Freddie_Mercury>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# True
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: award Order_of_the_British_Empire?
# False
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# True
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# True
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# True
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# True
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: award Kennedy_Center_Honors?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: award Order_of_the_Elephant?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Freddie_Mercury With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Freddie_Mercury>
#
#  <http://yago-knowledge.org/resource/Lady_Gaga>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# True
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# True
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# True
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: alumniOf Lee_Strasberg_Theatre_and_Film_Institute?
# True
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# True
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Lady_Gaga With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Lady_Gaga>
#
#  <http://yago-knowledge.org/resource/Heath_Ledger>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# True
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: nationality Canada?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage Spanish_language?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Heath_Ledger With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Heath_Ledger>
#
#  <http://yago-knowledge.org/resource/Serena_Williams>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# True
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# True
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Serena_Williams With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Serena_Williams>
#
#  <http://yago-knowledge.org/resource/Michael_Jackson>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# True
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# True
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# True
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# True
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Restaurateur?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Michael_Jackson With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Michael_Jackson>
#
#  <http://yago-knowledge.org/resource/Nancy_Pelosi>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# False
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: givenName George_(given_name)?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Nancy_Pelosi With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Nancy_Pelosi>
#
#  <http://yago-knowledge.org/resource/Bruce_Lee>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: nationality Canada?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage Spanish_language?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Bruce_Lee With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Bruce_Lee>
#
#  <http://yago-knowledge.org/resource/Alec_Baldwin>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: alumniOf Lee_Strasberg_Theatre_and_Film_Institute?
# True
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# True
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# True
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actress?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: award Kennedy_Center_Honors?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Alec_Baldwin With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Alec_Baldwin>
#
#  <http://yago-knowledge.org/resource/Novak_Djokovic>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# True
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# True
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: award Order_of_the_Elephant?
# False
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage Spanish_language?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Roger_Federer With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Novak_Djokovic>
#
#  <http://yago-knowledge.org/resource/Nicole_Kidman>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actress?
# True
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# True
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: alumniOf Lee_Strasberg_Theatre_and_Film_Institute?
# False
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Nicole_Kidman With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Nicole_Kidman>
#
#  <http://yago-knowledge.org/resource/Quentin_Tarantino>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.99
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.9801
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.9702989999999999
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.96059601
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# 0.9509900498999999
# Question: 6
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.9414801494009999
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# 0.9320653479069899
# Question: 8
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# True
# 0.92274469442792
# Question: 9
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# True
# 0.9135172474836407
# Question: 10
# Does the thing you are looking for have the attribute: award Kennedy_Center_Honors?
# False
# 0.9043820750088043
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.8953382542587163
# Question: 12
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.8863848717161291
# Question: 13
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.8775210229989678
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.8687458127689781
# Question: 15
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.8600583546412883
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.8514577710948754
# Question: 17
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# False
# 0.8429431933839266
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.8345137614500874
# Question: 19
# Does the thing you are looking for have the attribute: nationality Canada?
# False
# 0.8261686238355865
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# 0.8179069375972307
# The Answer is:  http://yago-knowledge.org/resource/Quentin_Tarantino With a Probability of:  0.8179069375972307
# <http://yago-knowledge.org/resource/Quentin_Tarantino>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#
# G:\conda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# G:\conda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# G:\conda\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# G:\conda\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# G:\conda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# G:\conda\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 500:
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-15-bbcd770fa7d9> in <module>
#      10 while gamesplayed < totalgames:
#      11     left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
# ---> 12     possibleObj, possiblePred, count = findSplits()
#      13     # Resets all variables
#      14     i=0
#
# <ipython-input-5-5c931767db5d> in findSplits()
#      31     sparql.setQuery(query)
#      32     sparql.setReturnFormat(JSON)
# ---> 33     qres = sparql.query().convert()
#      34     for r in qres["results"]["bindings"]:
#      35         possibleObj.append(r["o"]["value"])
#
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# G:\conda\lib\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1083                 raise URITooLong(e.read())
#    1084             elif e.code == 500:
# -> 1085                 raise EndPointInternalError(e.read())
#    1086             else:
#    1087                 raise e
#
# EndPointInternalError: EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Query evaluation error: Insufficient free Heap Memory 249Mb for group by and distinct, threshold:250Mb, reached 0Mb (HTTP status 500)\r\n'

# %%
wincount
# Out:
# 10

# %%
sum(Distribution.values())
# Out:
# 1.0050407038384892

# %%
print(subject[1:-1])
# Out:
# http://yago-knowledge.org/resource/Tina_Turner

# %%
print(numberleft("",""))
# Out:
# 134

# %%
NegFilters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-fce8c2121027> in <module>
# ----> 1 NegFilters
#
# NameError: name 'NegFilters' is not defined
