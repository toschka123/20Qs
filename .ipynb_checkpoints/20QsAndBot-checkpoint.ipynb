# %%
# %load_ext ipython_sparql_pandas
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper('http://DESKTOP-CELL0BF:7200/repositories/20final')
sparql.setReturnFormat(JSON)

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
import re
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    #print(listOfObj[0])
    return(listOfObj,listOfPred)

def generateQuestion(listOfPred, listOfObj, index):
    flag = True
    if ('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>') in AttrHistory:
        return generateQuestion(listOfPred, listOfObj, index+1)
        
    else:
        AttrHistory.append('<' + str(listOfPred[index]['value']) +'> <'+str(listOfObj[index]['value'])+ '>')
    userAnswer = input(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    try:
        int(listOfObj[index]['value'])
    except ValueError:
           flag = False
            
    if userAnswer.startswith('y'):
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.')    
        
    elif userAnswer.startswith('n'):
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}')   
        
    else:
        return generateQuestion(listOfPred, listOfObj, index+1)
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)


  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            group by ?p ?o 
            ORDER BY ABS( {left/2} - ?count )
            """) 
        
    return FilterQuestion

# %%
def numberleft(PosFilters,NegFilters):
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            {PosFilters}            
            {NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))
    
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            {PosFilters}
            {NegFilters} 
            }}
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    return qres["results"]["bindings"]

# %%
# resets are variables
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    left = numberleft(PosFilters,NegFilters)
    FilterQuestion = updateQuery(left, PosFilters, NegFilters)
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
"""PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
outofguess = []
NegFilters = "\n".join(NegAttr)
PosFilters = "\n".join(PosAttr)
left = numberleft(PosFilters,NegFilters)
print(left)
FilterQuestion = updateQuery(left, PosFilters, NegFilters)
sparql.setQuery(FilterQuestion)
sparql.setReturnFormat(JSON)
qres = sparql.query().convert()"""
i=0
left, qres, PosAttr, NegAttr, AttrHistory = game_reset()

while i<20:
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    if left <=1:
        break
    
    print('Question: %s' %(i+1))
    PosFilters, NegFilters = generateQuestion(listOfPred, listOfObj, 0)
    left = numberleft(PosFilters, NegFilters)
    query = updateQuery(left,PosFilters, NegFilters)
    sparql.setQuery(query)
    qres = sparql.queryAndConvert()
    
    i+=1
    
    # prints splits for top Pred and Objs 
    """print('remaining entities:', left)
    for r in qres["results"]["bindings"]:
        print(*[f'{x.split("/")[-1][:40]:40s}' for x in [r['count']["value"],r['p']["value"],r['o']["value"]]])"""
    
if i != 20:
    for attr in popentities(PosFilters, NegFilters):
        print(*[f'Your Answer is: {x.split("/")[-1]}' for x in [attr['s']['value']]][0:10]) 

        
else:
    print('Final Question:')
    for j in popentities(PosFilters, NegFilters):
            outofguess.append(f'{j["s"]["value"]}')
    guess = random.choice(outofguess)
    print(guess)
    answer = (input('Is this correct?').startswith('y'))
    if answer is True:
        print('Win')
    else:
        print('game over')
# Out:
# 4353
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language? n
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Actor? n
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States? n
# Question: 4
# Does the thing you are looking for have the attribute: nationality United_Kingdom? n
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer? n
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Football_player? n
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Writer? n
# Question: 8
# Does the thing you are looking for have the attribute: nationality India? n
# Question: 9
# Does the thing you are looking for have the attribute: knowsLanguage German_language? n
# Question: 10
# Does the thing you are looking for have the attribute: nationality Japan? n
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Politician? n
# Question: 12
# Does the thing you are looking for have the attribute: nationality Canada?
# Does the thing you are looking for have the attribute: hasOccupation Conductor_(music)? n
# Question: 13
# Does the thing you are looking for have the attribute: nationality Canada? n
# Question: 14
# Does the thing you are looking for have the attribute: knowsLanguage French_language? n
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Philosopher? n
# Question: 16
# Does the thing you are looking for have the attribute: nationality Germany? n
# Question: 17
# Does the thing you are looking for have the attribute: nationality France? n
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor? n
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# Does the thing you are looking for have the attribute: knowsLanguage Italian_language? n
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Pianist? n
# Final Question:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d0df6725d012> in <module>
#      41     print('Final Question:')
#      42     for j in popentities(PosFilters, NegFilters):
# ---> 43             outofguess.append(f'{j["s"].split("/")[-1][:40]:40s}')
#      44     guess = random.choice(outofguess)
#      45     print(guess)
#
# AttributeError: 'dict' object has no attribute 'split'

# %%
def generateBotQuestion(listOfPred, listOfObj, index, subject):
    flag = True
    try:
        int(listOfObj[index]['value'][0])
    except ValueError:
           flag = False
    print(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    if flag is True:
        datatype = listOfObj[index]["datatype"].split("#")[-1]
        answer = findAnswer(subject, '<' + str(listOfPred[index]["value"]) +'>', '"'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype)
    else:
        answer = findAnswer(subject, '<' + str(listOfPred[index]["value"]) +'>', '<'+str(listOfObj[index]["value"])+ '>')
    print(answer)
    
    if answer:
        #PosAttr.append('?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>.')    
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.')
        
    elif not answer:
        #NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>. }}')   
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}')   

    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)


def pickSubject():
    ind=randint(0,4325)
    query = f"""
    select distinct ?s
    where {{
        # ?s ?p ?o .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
    }}
    limit 4325
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"][ind:ind+1]:
        return("<"+r["s"]["value"]+">")

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
#without printing results
from random import randint
import random

wincount = 0
gamesplayed = 0
totalgames = 100

while gamesplayed < totalgames:
    left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
    # Resets all variables
    i=0
    outofguess = []

    # pick subject
    subject = pickSubject()
    print("\n" , subject)

    while i < 20:

        # list of Pred and Obj for questions
        listOfObj ,listOfPred = extractCountAndAttr(qres)

        # if only 1 popular entity is left break
        if left<=1:
            break

        # ask question and add filters to query
        print('Question: %s' %(i+1))
        PosFilters, NegFilters = generateBotQuestion(listOfPred, listOfObj, 0, subject)

        # number of popular entities left
        left = numberleft(PosFilters, NegFilters)

        # run query
        query = updateQuery(left/2,PosFilters, NegFilters)
        sparql.setQuery(query)
        qres = sparql.queryAndConvert()

        i+=1

    # Prints answer
    if i != 20:
        for attr in popentities(PosFilters, NegFilters):
            for x in [attr['s']['value']][0:10]:
                answer = (x.split("/")[-1])
        print("Your Answer is: " + answer)
        if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
            wincount += 1
            gamesplayed += 1
            print("Win!")
        else:
            gamesplayed += 1
            print("Lose...")

    # ran out of questions
    else:
        print('Final Question:')
        for j in popentities(PosFilters, NegFilters):
                outofguess.append(f'{j["s"]["value"].split("/")[-1]}')
        guess = random.choice(outofguess)
        print("Is it " + guess + "?")
        if str(subject.split("/")[-1]) == str(guess + ">"):
            wincount += 1
            gamesplayed += 1
            print('Win!')
        else:
            gamesplayed += 1
            print('Lose...')
            
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
#  <http://yago-knowledge.org/resource/Phyllis_Smith>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 9
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 10
# Does the thing you are looking for have the attribute: nationality Japan?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 12
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 13
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# True
# Question: 15
# Does the thing you are looking for have the attribute: image Carmen%20Electra%202011.jpg?
# False
# Question: 16
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Supporting_Actress?
# False
# Question: 17
# Does the thing you are looking for have the attribute: image Kevin%20McHale%20by%20Gage%20Skidmore.jpg?
# False
# Question: 18
# Does the thing you are looking for have the attribute: award NAACP_Image_Award_for_Outstanding_Female_Artist?
# False
# Question: 19
# Does the thing you are looking for have the attribute: alumniOf University_of_Missouri?
# True
# Your Answer is: Phyllis_Smith
# Win!
#
#  <http://yago-knowledge.org/resource/Robert_Patrick>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 9
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 10
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# Question: 11
# Does the thing you are looking for have the attribute: birthPlace Chicago?
# False
# Question: 12
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 14
# Does the thing you are looking for have the attribute: deathPlace Los_Angeles?
# False
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# False
# Question: 16
# Does the thing you are looking for have the attribute: birthPlace Pittsburgh?
# False
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 18
# Does the thing you are looking for have the attribute: birthPlace Detroit?
# False
# Question: 19
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Picture?
# False
# Question: 20
# Does the thing you are looking for have the attribute: alumniOf University_of_California,_Los_Angeles?
# False
# Final Question:
# Is it Joe_Pasternak?
# Lose...
#
#  <http://yago-knowledge.org/resource/Peter_Ustinov>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# True
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Novelist?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Television_director?
# False
# Question: 8
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# True
# Question: 9
# Does the thing you are looking for have the attribute: award Directors_Guild_of_America_Award?
# False
# Your Answer is: Peter_Ustinov
# Win!
#
#  <http://yago-knowledge.org/resource/Bonnie_Raitt>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# True
# Question: 7
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_New_Artist?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 10
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# False
# Question: 12
# Does the thing you are looking for have the attribute: givenName Bruce?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award Shortlist_Music_Prize?
# False
# Question: 14
# Does the thing you are looking for have the attribute: image Andrew%20WK.jpg?
# False
# Question: 15
# Does the thing you are looking for have the attribute: image Yann%20Tiersen%201.jpg?
# False
# Question: 16
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# False
# Question: 17
# Does the thing you are looking for have the attribute: givenName Michael?
# False
# Question: 18
# Does the thing you are looking for have the attribute: award MusiCares_Person_of_the_Year?
# True
# Your Answer is: Bonnie_Raitt
# Win!
#
#  <http://yago-knowledge.org/resource/Rainn_Wilson>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Director?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# False
# Question: 10
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# True
# Question: 11
# Does the thing you are looking for have the attribute: alumniOf USC_School_of_Cinematic_Arts?
# False
# Question: 12
# Does the thing you are looking for have the attribute: award National_Inventors_Hall_of_Fame?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award Edgar_Award?
# False
# Question: 14
# Does the thing you are looking for have the attribute: award Earle_Grey_Award?
# False
# Question: 15
# Does the thing you are looking for have the attribute: alumniOf New_York_University_Tisch_School_of_the_Arts?
# True
# Your Answer is: Rainn_Wilson
# Win!
#
#  <http://yago-knowledge.org/resource/Ann_Roth>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Football_player?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Cinematographer?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Conductor_(music)?
# False
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Scenographer?
# False
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Costume_designer?
# True
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Designer?
# True
# Question: 15
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 16
# Does the thing you are looking for have the attribute: image A%20Tailor-Made%20Man%20%281922%29%20-%202.jpg?
# False
# Question: 17
# Does the thing you are looking for have the attribute: award Costume_Designers_Guild_Award_for_Excellence_in_Period_Film?
# False
# Question: 18
# Does the thing you are looking for have the attribute: award Lenin_Peace_Prize?
# False
# Question: 19
# Does the thing you are looking for have the attribute: award Tony_Award_for_Best_Costume_Design_in_a_Play?
# True
# Your Answer is: Ann_Roth
# Win!
#
#  <http://yago-knowledge.org/resource/Vera_Farmiga>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 6
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Theatre_director?
# False
# Question: 9
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Regisseur?
# False
# Question: 11
# Does the thing you are looking for have the attribute: birthPlace Chicago?
# False
# Question: 12
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 13
# Does the thing you are looking for have the attribute: alumniOf New_York_University_Tisch_School_of_the_Arts?
# False
# Question: 14
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Television_presenter?
# False
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Television_director?
# False
# Question: 17
# Does the thing you are looking for have the attribute: award Directors_Guild_of_America_Award?
# False
# Question: 18
# Does the thing you are looking for have the attribute: award Empire_Award_for_Best_Actress?
# False
# Question: 19
# Does the thing you are looking for have the attribute: award Dora_Mavor_Moore_Award?
# False
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Final Question:
# Is it Vin_Diesel?
# Lose...
#
#  <http://yago-knowledge.org/resource/W._H._Auden>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# True
# Question: 6
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# True
# Question: 7
# Does the thing you are looking for have the attribute: deathPlace London?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Philosopher?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Librettist?
# True
# Question: 10
# Does the thing you are looking for have the attribute: award Pulitzer_Prize_for_Poetry?
# True
# Your Answer is: W._H._Auden
# Win!
#
#  <http://yago-knowledge.org/resource/Immanuel_Kant>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Football_player?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 10
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# False
# Question: 12
# Does the thing you are looking for have the attribute: nationality Russian_Empire?
# True
# Question: 13
# Does the thing you are looking for have the attribute: award Hero_of_Socialist_Labour?
# False
# Question: 14
# Does the thing you are looking for have the attribute: award Pushkin_Prize?
# False
# Question: 15
# Does the thing you are looking for have the attribute: image Leo%20Tolstoy%2C%20portrait.jpg?
# False
# Question: 16
# Does the thing you are looking for have the attribute: alumniOf University_of_Königsberg?
# True
# Your Answer is: Immanuel_Kant
# Win!
#
#  <http://yago-knowledge.org/resource/Takeshi_Kitano>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 9
# Does the thing you are looking for have the attribute: award Golden_Lion?
# True
# Your Answer is: Takeshi_Kitano
# Win!
#
#  <http://yago-knowledge.org/resource/George_Abbott>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Theatre_director?
# True
# Question: 7
# Does the thing you are looking for have the attribute: award Donostia_Award?
# False
# Question: 8
# Does the thing you are looking for have the attribute: award Cannes_Film_Festival?
# False
# Question: 9
# Does the thing you are looking for have the attribute: award List_of_recipients_of_the_National_Medal_of_Arts?
# True
# Your Answer is: George_Abbott
# Win!
#
#  <http://yago-knowledge.org/resource/Gulzar>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Novelist?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Television_director?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# True
# Question: 11
# Does the thing you are looking for have the attribute: award Order_of_Friendship?
# False
# Question: 12
# Does the thing you are looking for have the attribute: award National_Prize_of_the_German_Democratic_Republic?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award Sahitya_Akademi_Award?
# True
# Your Answer is: Gulzar
# Win!
#
#  <http://yago-knowledge.org/resource/Thandie_Newton>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 9
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# True
# Question: 10
# Does the thing you are looking for have the attribute: birthPlace London?
# True
# Question: 11
# Does the thing you are looking for have the attribute: nationality Canada?
# False
# Question: 12
# Does the thing you are looking for have the attribute: image Dev%20Patel%20TIFF%202011.jpg?
# False
# Question: 13
# Does the thing you are looking for have the attribute: alumniOf University_of_Cambridge?
# True
# Your Answer is: Thandie_Newton
# Win!
#
#  <http://yago-knowledge.org/resource/Raphael_Saadiq>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# True
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# False
# Question: 11
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# False
# Question: 12
# Does the thing you are looking for have the attribute: award People's_Choice_Award_for_Favorite_Female_Artist?
# False
# Question: 13
# Does the thing you are looking for have the attribute: familyName Williams_(surname)?
# False
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Music_executive?
# True
# Question: 15
# Does the thing you are looking for have the attribute: alumniOf Manhattan_School_of_Music?
# False
# Your Answer is: Raphael_Saadiq
# Win!
#
#  <http://yago-knowledge.org/resource/Kim_Stanley_Robinson>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 9
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# Question: 10
# Does the thing you are looking for have the attribute: award Hugo_Award_for_Best_Novel?
# True
# Question: 11
# Does the thing you are looking for have the attribute: award Grand_prix_de_l'Imaginaire?
# False
# Question: 12
# Does the thing you are looking for have the attribute: award Hugo_Award_for_Best_Short_Story?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award John_W._Campbell_Memorial_Award_for_Best_Science_Fiction_Novel?
# True
# Question: 14
# Does the thing you are looking for have the attribute: award Prometheus_Award?
# False
# Your Answer is: Kim_Stanley_Robinson
# Win!
#
#  <http://yago-knowledge.org/resource/Michael_Murphy_(actor)>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 9
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 10
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# True
# Question: 11
# Does the thing you are looking for have the attribute: alumniOf University_of_California,_Los_Angeles?
# True
# Question: 12
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Actress?
# False
# Question: 13
# Does the thing you are looking for have the attribute: image Ryan%20Kavanaugh.JPG?
# False
# Your Answer is: Michael_Murphy_(actor)
# Win!
#
#  <http://yago-knowledge.org/resource/Dario_Argento>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 5
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# False
# Question: 7
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace Chicago?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Television_director?
# False
# Question: 12
# Does the thing you are looking for have the attribute: nationality China?
# False
# Question: 13
# Does the thing you are looking for have the attribute: nationality Canada?
# False
# Question: 14
# Does the thing you are looking for have the attribute: alumniOf New_York_University_Tisch_School_of_the_Arts?
# False
# Question: 15
# Does the thing you are looking for have the attribute: nationality Japan?
# False
# Question: 16
# Does the thing you are looking for have the attribute: award Golden_Lion?
# False
# Question: 17
# Does the thing you are looking for have the attribute: deathPlace Los_Angeles?
# False
# Question: 18
# Does the thing you are looking for have the attribute: deathPlace Hollywood?
# False
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Theatre_director?
# False
# Question: 20
# Does the thing you are looking for have the attribute: givenName Robert?
# False
# Final Question:
# Is it Sean_McNamara_(director)?
# Lose...
#
#  <http://yago-knowledge.org/resource/Michael_Moriarty>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 8
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# True
# Question: 9
# Does the thing you are looking for have the attribute: award Tony_Award_for_Best_Book_of_a_Musical?
# False
# Question: 10
# Does the thing you are looking for have the attribute: award Jefferson_Lecture?
# False
# Your Answer is: Michael_Moriarty
# Win!
#
#  <http://yago-knowledge.org/resource/Robert_Chartoff>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 9
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# True
# Question: 10
# Does the thing you are looking for have the attribute: givenName Robert?
# True
# Question: 11
# Does the thing you are looking for have the attribute: alumniOf University_of_Miami?
# False
# Your Answer is: Robert_Chartoff
# Win!
#
#  <http://yago-knowledge.org/resource/Debbie_Harry>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# Question: 7
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 9
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 10
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 11
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Actress_in_a_Motion_Picture_–_Drama?
# False
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 13
# Does the thing you are looking for have the attribute: alumniOf William_Esper_Studio?
# False
# Question: 14
# Does the thing you are looking for have the attribute: award Tony_Award_for_Best_Featured_Actor_in_a_Play?
# False
# Question: 15
# Does the thing you are looking for have the attribute: givenName Michelle_(name)?
# False
# Question: 16
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 17
# Does the thing you are looking for have the attribute: nationality Republic_of_Ireland?
# False
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# Question: 19
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_Pop_Collaboration_with_Vocals?
# False
# Your Answer is: Debbie_Harry
# Win!
#
#  <http://yago-knowledge.org/resource/Franz_Waxman>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Football_player?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Cinematographer?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Conductor_(music)?
# True
# Question: 12
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Original_Score?
# False
# Question: 14
# Does the thing you are looking for have the attribute: nationality Germany?
# True
# Question: 15
# Does the thing you are looking for have the attribute: award Pour_le_Mérite?
# False
# Question: 16
# Does the thing you are looking for have the attribute: deathDate 1967-02-24?
# True
# Your Answer is: Franz_Waxman
# Win!
#
#  <http://yago-knowledge.org/resource/Walter_M._Scott>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Football_player?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Cinematographer?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Conductor_(music)?
# False
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Scenographer?
# True
# Question: 13
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Production_Design?
# True
# Question: 14
# Does the thing you are looking for have the attribute: deathPlace Woodland_Hills,_Los_Angeles?
# False
# Question: 15
# Does the thing you are looking for have the attribute: givenName Henry_(given_name)?
# False
# Question: 16
# Does the thing you are looking for have the attribute: alumniOf Norwich_University_of_the_Arts?
# False
# Question: 17
# Does the thing you are looking for have the attribute: alumniOf Art_Students_League_of_New_York?
# False
# Question: 18
# Does the thing you are looking for have the attribute: deathDate 1959-03-02?
# False
# Question: 19
# Does the thing you are looking for have the attribute: alumniOf Chouinard_Art_Institute?
# False
# Question: 20
# Does the thing you are looking for have the attribute: deathDate 1989-02-02?
# True
# Final Question:
# Is it Walter_M._Scott?
# Win!
#
#  <http://yago-knowledge.org/resource/Dina_Pathak>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# True
# Question: 8
# Does the thing you are looking for have the attribute: knowsLanguage Malayalam?
# False
# Question: 9
# Does the thing you are looking for have the attribute: deathPlace Mumbai?
# True
# Question: 10
# Does the thing you are looking for have the attribute: award Padma_Bhushan?
# False
# Question: 11
# Does the thing you are looking for have the attribute: alumniOf R._D._National_College?
# False
# Question: 12
# Does the thing you are looking for have the attribute: deathDate 2013-07-28?
# False
# Question: 13
# Does the thing you are looking for have the attribute: deathDate 2007-10-27?
# False
# Question: 14
# Does the thing you are looking for have the attribute: award Sangeet_Natak_Akademi_Award?
# True
# Your Answer is: Dina_Pathak
# Win!
#
#  <http://yago-knowledge.org/resource/Harold_Ramis>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Director?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# False
# Question: 10
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 11
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Original_Screenplay?
# False
# Question: 12
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 13
# Does the thing you are looking for have the attribute: givenName David_(name)?
# False
# Question: 14
# Does the thing you are looking for have the attribute: deathPlace Los_Angeles?
# False
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Regisseur?
# True
# Question: 16
# Does the thing you are looking for have the attribute: award Ray_Bradbury_Award?
# False
# Question: 17
# Does the thing you are looking for have the attribute: award Online_Film_Critics_Society_Award_for_Best_Ensemble?
# False
# Question: 18
# Does the thing you are looking for have the attribute: award Earle_Grey_Award?
# True
# Your Answer is: Harold_Ramis
# Win!
#
#  <http://yago-knowledge.org/resource/Lena_Headey>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# True
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 12
# Does the thing you are looking for have the attribute: givenName David_(name)?
# False
# Question: 13
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# False
# Question: 14
# Does the thing you are looking for have the attribute: alumniOf St_Edward's_School,_Oxford?
# False
# Question: 15
# Does the thing you are looking for have the attribute: image Marianne%20Faithfull%202007.jpg?
# False
# Question: 16
# Does the thing you are looking for have the attribute: alumniOf Shelley_College?
# True
# Your Answer is: Lena_Headey
# Win!
#
#  <http://yago-knowledge.org/resource/Kris_Kristofferson>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 12
# Does the thing you are looking for have the attribute: birthPlace Houston?
# False
# Question: 13
# Does the thing you are looking for have the attribute: givenName John_(given_name)?
# False
# Question: 14
# Does the thing you are looking for have the attribute: alumniOf Brooklyn_College_Academy?
# False
# Question: 15
# Does the thing you are looking for have the attribute: alumniOf USC_School_of_Cinematic_Arts?
# False
# Question: 16
# Does the thing you are looking for have the attribute: image Malcolm%20David%20Kelley%20PaleyFest%202014.jpg?
# False
# Question: 17
# Does the thing you are looking for have the attribute: alumniOf Oral_Roberts_University?
# False
# Question: 18
# Does the thing you are looking for have the attribute: award Latin_Grammy_Award_for_Best_Rock_Album?
# False
# Question: 19
# Does the thing you are looking for have the attribute: award Rhodes_Scholarship?
# True
# Your Answer is: Kris_Kristofferson
# Win!
#
#  <http://yago-knowledge.org/resource/Elmer_Bernstein>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# True
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# True
# Question: 9
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# True
# Question: 10
# Does the thing you are looking for have the attribute: award Grammy_Trustees_Award?
# False
# Question: 11
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Original_Score?
# True
# Your Answer is: Elmer_Bernstein
# Win!
#
#  <http://yago-knowledge.org/resource/Leonard_Nimoy>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Director?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# True
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Artist?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Photographer?
# True
# Question: 12
# Does the thing you are looking for have the attribute: award Bodil_Honorary_Award?
# False
# Your Answer is: Leonard_Nimoy
# Win!
#
#  <http://yago-knowledge.org/resource/Warren_Feeney>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Football_player?
# True
# Question: 9
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 10
# Does the thing you are looking for have the attribute: memberOf Oldham_Athletic_A.F.C.?
# True
# Question: 11
# Does the thing you are looking for have the attribute: alumniOf Staffordshire_University?
# False
# Question: 12
# Does the thing you are looking for have the attribute: image FullerStoke.jpg?
# False
# Question: 13
# Does the thing you are looking for have the attribute: nationality Grenada?
# False
# Question: 14
# Does the thing you are looking for have the attribute: alumniOf Ashfield_Boys'_High_School?
# True
# Your Answer is: Warren_Feeney
# Win!
#
#  <http://yago-knowledge.org/resource/Nunnally_Johnson>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 5
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# False
# Question: 7
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace Chicago?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# Question: 10
# ...
# False
# Question: 9
# Does the thing you are looking for have the attribute: award Donostia_Award?
# True
# Your Answer is: Francis_Ford_Coppola
# Win!
#
#  <http://yago-knowledge.org/resource/Ruth_Gordon>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 6
# Does the thing you are looking for have the attribute: award Kennedy_Center_Honors?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace Chicago?
# False
# Question: 9
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# Question: 10
# Does the thing you are looking for have the attribute: alumniOf Wellington_College,_Berkshire?
# False
# Question: 11
# Does the thing you are looking for have the attribute: image Vincent%20D%27Onofrio%20TIFF%202014.jpg?
# False
# Question: 12
# Does the thing you are looking for have the attribute: alumniOf Stuyvesant_High_School?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Supporting_Actress?
# True
# Your Answer is: Ruth_Gordon
# Win!
#
#  <http://yago-knowledge.org/resource/Ed_McMahon>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 9
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 10
# Does the thing you are looking for have the attribute: nationality Japan?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 12
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 13
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# False
# Question: 15
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# Question: 16
# Does the thing you are looking for have the attribute: alumniOf New_York_University_Tisch_School_of_the_Arts?
# False
# Question: 17
# Does the thing you are looking for have the attribute: award Screen_Actors_Guild_Award_for_Outstanding_Performance_by_an_Ensemble_in_a_Drama_Series?
# False
# Question: 18
# Does the thing you are looking for have the attribute: nationality Canada?
# False
# Question: 19
# Does the thing you are looking for have the attribute: birthPlace Chicago?
# False
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Final Question:
# Is it Gary_Dourdan?
# Lose...
#
#  <http://yago-knowledge.org/resource/Emma_Watson>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 7
# Does the thing you are looking for have the attribute: alumniOf Royal_Academy_of_Dramatic_Art?
# False
# Question: 8
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actor?
# False
# Question: 9
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# Question: 10
# Does the thing you are looking for have the attribute: alumniOf Guildhall_School_of_Music_and_Drama?
# False
# Question: 11
# Does the thing you are looking for have the attribute: birthPlace London?
# False
# Question: 12
# Does the thing you are looking for have the attribute: award Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actress?
# False
# Question: 14
# Does the thing you are looking for have the attribute: givenName Charlotte_(given_name)?
# True
# Question: 15
# Does the thing you are looking for have the attribute: alumniOf Headington_School?
# True
# Your Answer is: Emma_Watson
# Win!
#
#  <http://yago-knowledge.org/resource/Jerry_O'Connell>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 11
# Does the thing you are looking for have the attribute: award Inkpot_Award?
# False
# Question: 12
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# False
# Question: 13
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 14
# Does the thing you are looking for have the attribute: alumniOf University_of_California,_Los_Angeles?
# False
# Question: 15
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# False
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 17
# Does the thing you are looking for have the attribute: alumniOf New_York_University_Tisch_School_of_the_Arts?
# True
# Question: 18
# Does the thing you are looking for have the attribute: image Damon%20Lindelof%20by%20Gage%20Skidmore%203.jpg?
# False
# Question: 19
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Adapted_Screenplay?
# False
# Question: 20
# Does the thing you are looking for have the attribute: alumniOf Southwestern_Law_School?
# True
# Final Question:
# Is it Jerry_O'Connell?
# Win!
#
#  <http://yago-knowledge.org/resource/Charles_Durning>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 4
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 6
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# Question: 7
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 9
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# False
# Question: 10
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 11
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 12
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 13
# Does the thing you are looking for have the attribute: deathPlace Los_Angeles?
# False
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 15
# Does the thing you are looking for have the attribute: nationality Canada?
# False
# Question: 16
# Does the thing you are looking for have the attribute: memberOf California_Republican_Party?
# False
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# False
# Question: 18
# Does the thing you are looking for have the attribute: nationality Republic_of_Ireland?
# False
# Question: 19
# Does the thing you are looking for have the attribute: alumniOf Neighborhood_Playhouse_School_of_the_Theatre?
# False
# Question: 20
# Does the thing you are looking for have the attribute: alumniOf American_Academy_of_Dramatic_Arts?
# True
# Final Question:
# Is it Charles_Durning?
# Win!
#
#  <http://yago-knowledge.org/resource/Gary_Summers>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Football_player?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Cinematographer?
# False
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Conductor_(music)?
# False
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Scenographer?
# False
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Costume_designer?
# False
# Question: 14
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 15
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Audio_engineer?
# True
# Question: 17
# Does the thing you are looking for have the attribute: givenName Mark_(given_name)?
# False
# Question: 18
# Does the thing you are looking for have the attribute: givenName Michael?
# False
# Question: 19
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Sound_Editing?
# False
# Question: 20
# Does the thing you are looking for have the attribute: birthPlace New_York_City?
# False
# Final Question:
# Is it Kevin_O'Connell_(sound_mixer)?
# Lose...
#
#  <http://yago-knowledge.org/resource/Vanilla_Ice>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 7
# Does the thing you are looking for have the attribute: nationality India?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# True
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 11
# Does the thing you are looking for have the attribute: award Latin_Grammy_Award_for_Song_of_the_Year?
# False
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Drummer?
# False
# Question: 14
# Does the thing you are looking for have the attribute: nationality China?
# False
# Question: 15
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_New_Artist?
# False
# Question: 16
# Does the thing you are looking for have the attribute: image Rory%20Cochrane%20at%20the%20premiere%20of%20Argo%2C%20Toronto%20Film%20Festival%202012.jpg?
# False
# Question: 17
# Does the thing you are looking for have the attribute: image Andy%20Williams%201963.JPG?
# False
# Question: 18
# Does the thing you are looking for have the attribute: image Akon%20in%20July%202015%20%28cropped%29.jpg?
# False
# Question: 19
# Does the thing you are looking for have the attribute: alumniOf Cerritos_College?
# False
# Question: 20
# Does the thing you are looking for have the attribute: nationality Japan?
# False
# Final Question:
# Is it Jay_Chou?
# Lose...
#
#  <http://yago-knowledge.org/resource/Rainn_Wilson>
# Question: 1
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# Question: 7
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Director?
# False
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Television_producer?
# False
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# False
# Question: 10
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# True
# Question: 11
# Does the thing you are looking for have the attribute: alumniOf USC_School_of_Cinematic_Arts?
# False
# Question: 12
# Does the thing you are looking for have the attribute: award National_Inventors_Hall_of_Fame?
# False
# Question: 13
# Does the thing you are looking for have the attribute: award Edgar_Award?
# False
# Question: 14
# Does the thing you are looking for have the attribute: award Earle_Grey_Award?
# False
# Question: 15
# Does the thing you are looking for have the attribute: alumniOf New_York_University_Tisch_School_of_the_Arts?
# True
# Your Answer is: Rainn_Wilson
# Win!
#
# Tournament ended! I have guessed 76 out of 100 things correctly.
