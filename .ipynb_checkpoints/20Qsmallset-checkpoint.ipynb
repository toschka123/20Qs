# %%
# %load_ext ipython_sparql_pandas
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper('http://DESKTOP-D6TQ7G4:7200/repositories/20qs')
sparql.setReturnFormat(JSON)
# Out:
# The ipython_sparql_pandas extension is already loaded. To reload it, use:
#   %reload_ext ipython_sparql_pandas

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
import re
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def prepareProps(popEntities):
    Distribution = {}
    for i in range(0,len(popEntities)):
        Distribution{i:1/len(popEntities}
    return Distribution


def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    #print(listOfObj[0])
    return(listOfObj,listOfPred)

def generateQuestion(listOfPred, listOfObj, index):
    flag = True
    if ('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>') in AttrHistory:
        return generateQuestion(listOfPred, listOfObj, index+1)
        
    else:
        AttrHistory.append('<' + str(listOfPred[index]['value']) +'> <'+str(listOfObj[index]['value'])+ '>')
    userAnswer = input(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    try:
        int(listOfObj[index]['value'])
    except ValueError:
           flag = False
            
    if userAnswer.startswith('y'):
        
        """if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.')   """ 
        
    elif userAnswer.startswith('n'):
        """if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}')   """
        
    else:
        return generateQuestion(listOfPred, listOfObj, index+1)
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)


  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            group by ?p ?o 
            ORDER BY ABS( {left/2} - ?count )
            """) 
        
    return FilterQuestion

# %%
def numberleft(PosFilters,NegFilters):
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            {PosFilters}            
            {NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))
    
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            {PosFilters}
            {NegFilters} 
            }}
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    return qres["results"]["bindings"]

# %%
# resets are variables
def game_reset():
    PosAttr= ['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
    NegAttr= ['']
    AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    left = numberleft(PosFilters,NegFilters)
    FilterQuestion = updateQuery(left, PosFilters, NegFilters)
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
"""PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
outofguess = []
NegFilters = "\n".join(NegAttr)
PosFilters = "\n".join(PosAttr)
left = numberleft(PosFilters,NegFilters)
print(left)
FilterQuestion = updateQuery(left, PosFilters, NegFilters)
sparql.setQuery(FilterQuestion)
sparql.setReturnFormat(JSON)
qres = sparql.query().convert()"""
i=0
left, qres, PosAttr, NegAttr, AttrHistory = game_reset()

while i<20:
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    if left <=1:
        break
    
    print('Question: %s' %(i+1))
    PosFilters, NegFilters = generateQuestion(listOfPred, listOfObj, 0)
    left = numberleft(PosFilters, NegFilters)
    query = updateQuery(left,PosFilters, NegFilters)
    sparql.setQuery(query)
    qres = sparql.queryAndConvert()
    
    i+=1
    
    # prints splits for top Pred and Objs 
    """print('remaining entities:', left)
    for r in qres["results"]["bindings"]:
        print(*[f'{x.split("/")[-1][:40]:40s}' for x in [r['count']["value"],r['p']["value"],r['o']["value"]]])"""
    
if i != 20:
    for attr in popentities(PosFilters, NegFilters):
        print(*[f'Your Answer is: {x.split("/")[-1]}' for x in [attr['s']['value']]][0:10]) 

        
else:
    print('Final Question:')
    for j in popentities(PosFilters, NegFilters):
            outofguess.append(f'{j["s"]["value"]}')
    guess = random.choice(outofguess)
    print(guess)
    answer = (input('Is this correct?').startswith('y'))
    if answer is True:
        print('Win')
    else:
        print('game over')
# Out:
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor? y
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer? n
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States? y
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Businessperson? n
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter? n
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)? n
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter? y
# Question: 8
# Does the thing you are looking for have the attribute: image 191125%20Taylor%20Swift%20at%20the%202019%20American%20Music%20Awards.png? n
# Question: 9
# Does the thing you are looking for have the attribute: image Demi%20Lovato%20%28Red%20carpet%29%20-%20Global%20Citizen%20Festival%20Hamburg%2007.jpg? i
# Does the thing you are looking for have the attribute: image Marilyn%20Manson%20Cannes.jpg? i
# Does the thing you are looking for have the attribute: birthPlace Albuquerque,_New_Mexico? nn
# Your Answer is: Marilyn_Manson

# %%
def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i]= 1/len(popEntities)
    return Distribution
    
print(prepareProps(["Oma", "Opa"]))

def findPosAndNeg(listOfObj, listOfPred, index):
    Filter = '?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.'
    negFilter='FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}'
    EntitiesPositive = popEntities(Filter, [])
    EntitiesNegative = popEntities([], negFilter)
    return (EntitiesPositive, EntitiesNegative)
    

def generateQuestion(listOfObj, listOfPred, index):
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    if userAnswer.startswith('y'):
        for y in yes:
            Distribution[y] = Distribution[y] * 2
        for n in no:
            Distribution[n] = Distribution[n] / 2
            
    elif userAnswer.startswith('n'):
        for y in yes:
            Distribution[y] = Distribution[y] / 2
        for n in no:
            Distribution[n] = Distribution[n] * 2
    
    return Distribution
                       
def findSplits():
    query =  f"""
            select (count(?s) as ?count)   ?o ?p
            {{               
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
        # ?s ?p ?o.
            }}
group by  ?o ?p
ORDER BY desc ( ?count )
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    return qres["results"]["bindings"]
# Out:
# {'Oma': 0.5, 'Opa': 0.5}

# %%
    query =  f"""
            select (count(?s) as ?count)   ?o ?p
            {{               
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
        # ?s ?p ?o.
            }}
group by  ?o ?p
ORDER BY desc ( ?count )
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    print(qres)
# Out:
# {'head': {'vars': ['count', 'o', 'p']}, 'results': {'bindings': [{'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '134'}, 'o': {'type': 'uri', 'value': 'http://example.com/popularEntity'}, 'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '134'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Human'}, 'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '117'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/English_language'}, 'p': {'type': 'uri', 'value': 'http://schema.org/knowsLanguage'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '93'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/United_States'}, 'p': {'type': 'uri', 'value': 'http://schema.org/nationality'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '77'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Actor'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '51'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Film_producer'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '37'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Screenwriter'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '32'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Film_director'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '29'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Democratic_Party_(United_States)'}, 'p': {'type': 'uri', 'value': 'http://schema.org/memberOf'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '25'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Stage_actor'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '21'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Politician'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '21'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Singer-songwriter'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '21'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/United_Kingdom'}, 'p': {'type': 'uri', 'value': 'http://schema.org/nationality'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '19'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Los_Angeles'}, 'p': {'type': 'uri', 'value': 'http://schema.org/homeLocation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '18'}, 'o': {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Songwriter'}, 'p': {'type': 'uri', 'value': 'http://schema.org/hasOccupation'}}, {'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '16'}, 'o': {'type': 'uri', 'value': 'http://yago-k ...

# %%
def generateBotQuestion(listOfPred, listOfObj, index, subject):
    flag = True
    try:
        int(listOfObj[index]['value'][0])
    except ValueError:
           flag = False
    print(f'Does the thing you are looking for have the attribute: {listOfPred[index]["value"].split("/")[-1]} {listOfObj[index]["value"].split("/")[-1]}?' )
    
    if flag is True:
        datatype = listOfObj[index]["datatype"].split("#")[-1]
        answer = findAnswer(subject, '<' + str(listOfPred[index]["value"]) +'>', '"'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype)
    else:
        answer = findAnswer(subject, '<' + str(listOfPred[index]["value"]) +'>', '<'+str(listOfObj[index]["value"])+ '>')
    print(answer)
    
    if answer:
        #PosAttr.append('?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>.')    
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'.') 
        else:
            PosAttr.append('?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>.')
        
    elif not answer:
        #NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>. }}')   
        if flag is True:
            datatype = listOfObj[index]["datatype"].split("#")[-1]
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> "'+str(listOfObj[index]["value"])+'"^^xsd:'+datatype+'. }}')
        else:
            NegAttr.append('FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]["value"]) +'> <'+str(listOfObj[index]["value"])+ '>. }}')   

    NegFilters = "\n".join(NegAttr)
    PosFilters = "\n".join(PosAttr)
    return (PosFilters, NegFilters)


def pickSubject():
    ind=randint(0,134)
    query = f"""
    select distinct ?s
    where {{
        # ?s ?p ?o .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
    }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"][ind:ind+1]:
        return("<"+r["s"]["value"]+">")

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
#without printing results
from random import randint
import random

wincount = 0
gamesplayed = 0
totalgames = 25

while gamesplayed < totalgames:
    left,qres,PosAttr,NegAttr,AttrHistory = game_reset()
    # Resets all variables
    i=0
    outofguess = []

    # pick subject
    subject = pickSubject()
    print("\n" , subject)

    while i < 20:

        # list of Pred and Obj for questions
        listOfObj ,listOfPred = extractCountAndAttr(qres)

        # if only 1 popular entity is left break
        if left<=1:
            break

        # ask question and add filters to query
        print('Question: %s' %(i+1))
        PosFilters, NegFilters = generateBotQuestion(listOfPred, listOfObj, 0, subject)

        # number of popular entities left
        left = numberleft(PosFilters, NegFilters)

        # run query
        query = updateQuery(left/2,PosFilters, NegFilters)
        sparql.setQuery(query)
        qres = sparql.queryAndConvert()

        i+=1

    # Prints answer
    if i != 20:
        for attr in popentities(PosFilters, NegFilters):
            for x in [attr['s']['value']][0:10]:
                answer = (x.split("/")[-1])
        print("Your Answer is: " + answer)
        if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
            wincount += 1
            gamesplayed += 1
            print("Win!")
        else:
            gamesplayed += 1
            print("Lose...")

    # ran out of questions
    else:
        print('Final Question:')
        for j in popentities(PosFilters, NegFilters):
                outofguess.append(f'{j["s"]["value"].split("/")[-1]}')
        guess = random.choice(outofguess)
        print("Is it " + guess + "?")
        if str(subject.split("/")[-1]) == str(guess + ">"):
            wincount += 1
            gamesplayed += 1
            print('Win!')
        else:
            gamesplayed += 1
            print('Lose...')
            
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
#  <http://yago-knowledge.org/resource/Albert_Einstein>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: memberOf American_Philosophical_Society?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image Albert%20Einstein%20Head.jpg?
# True
# Your Answer is: Albert_Einstein
# Win!
#
#  <http://yago-knowledge.org/resource/Marilyn_Manson>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Child_actor?
# False
# Question: 6
# Does the thing you are looking for have the attribute: alumniOf Liverpool_Institute_High_School_for_Boys?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image 191125%20Taylor%20Swift%20at%20the%202019%20American%20Music%20Awards.png?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image David-Bowie%20Chicago%202002-08-08%20photoby%20Adam-Bielawski-cropped.jpg?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Eminem%20live%20at%20D.C.%202014%20%28cropped%29.jpg?
# False
# Question: 10
# Does the thing you are looking for have the attribute: image JohnLennonpeace.jpg?
# False
# Question: 11
# Does the thing you are looking for have the attribute: image Marilyn%20Manson%20Cannes.jpg?
# True
# Your Answer is: Marilyn_Manson
# Win!
#
#  <http://yago-knowledge.org/resource/Sandra_Bullock>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# Question: 4
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# True
# Question: 7
# Does the thing you are looking for have the attribute: image Arnold%20Schwarzenegger%20by%20Gage%20Skidmore%204.jpg?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image Sandra%20Bullock%202010.jpg?
# True
# Your Answer is: Sandra_Bullock
# Win!
#
#  <http://yago-knowledge.org/resource/Macaulay_Culkin>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actress?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# False
# Question: 6
# Does the thing you are looking for have the attribute: image Carey%20Mulligan%20-%202018%20%2845646489364%29%20%28cropped%29.jpg?
# False
# Question: 7
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image Jennifer%20Aniston%2008.jpg?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Judy%20Garland%20The%20Harvey%20Girls%20MGM%20Publicity%20still.jpeg?
# False
# Question: 10
# Does the thing you are looking for have the attribute: image Leonardo%20Dicaprio%20Cannes%202019.jpg?
# False
# Question: 11
# Does the thing you are looking for have the attribute: image Macaulay%20Culkin%20singing%20%282010%29.jpg?
# True
# Your Answer is: Macaulay_Culkin
# Win!
#
#  <http://yago-knowledge.org/resource/Stanley_Tucci>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 4
# Does the thing you are looking for have the attribute: image Alec%20Baldwin%20Cannes%202012.jpg?
# False
# Question: 5
# Does the thing you are looking for have the attribute: image John%20Krasinski%202018.png?
# False
# Question: 6
# Does the thing you are looking for have the attribute: image Olivia%20Wilde%20at%20the%20Red%20Carpet%20Premiere%20of%20A%20Vigilante%20during%20SXSW%202018%20%2840704996872%29%20%28cropped%29.jpg?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image Rachel%20Weisz%20Cannes%202015%202.jpg?
# False
# Your Answer is: Stanley_Tucci
# Win!
#
#  <http://yago-knowledge.org/resource/Demi_Lovato>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Child_actor?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image 191125%20Selena%20Gomez%20at%20the%202019%20American%20Music%20Awards.png?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image Demi%20Lovato%20%28Red%20carpet%29%20-%20Global%20Citizen%20Festival%20Hamburg%2007.jpg?
# True
# Your Answer is: Demi_Lovato
# Win!
#
#  <http://yago-knowledge.org/resource/John_F._Kennedy>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# Question: 3
# Does the thing you are looking for have the attribute: alumniOf Columbia_University?
# False
# Question: 4
# Does the thing you are looking for have the attribute: award Ellis_Island_Medal_of_Honor?
# False
# Question: 5
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image John%20F.%20Kennedy%2C%20White%20House%20color%20photo%20portrait.jpg?
# True
# Your Answer is: John_F._Kennedy
# Win!
#
#  <http://yago-knowledge.org/resource/Jake_Gyllenhaal>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# Question: 3
# Does the thing you are looking for have the attribute: alumniOf Columbia_University?
# True
# Question: 4
# Does the thing you are looking for have the attribute: image Froosevelt.jpeg?
# False
# Question: 5
# Does the thing you are looking for have the attribute: image Jake%20Gyllenhaal%202019%20by%20Glenn%20Francis.jpg?
# True
# Your Answer is: Jake_Gyllenhaal
# Win!
#
#  <http://yago-knowledge.org/resource/Marilyn_Manson>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Child_actor?
# False
# Question: 6
# Does the thing you are looking for have the attribute: alumniOf Liverpool_Institute_High_School_for_Boys?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image 191125%20Taylor%20Swift%20at%20the%202019%20American%20Music%20Awards.png?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image David-Bowie%20Chicago%202002-08-08%20photoby%20Adam-Bielawski-cropped.jpg?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Eminem%20live%20at%20D.C.%202014%20%28cropped%29.jpg?
# False
# Question: 10
# Does the thing you are looking for have the attribute: image JohnLennonpeace.jpg?
# False
# Question: 11
# Does the thing you are looking for have the attribute: image Marilyn%20Manson%20Cannes.jpg?
# True
# Your Answer is: Marilyn_Manson
# Win!
#
#  <http://yago-knowledge.org/resource/Stanley_Tucci>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# Question: 4
# Does the thing you are looking for have the attribute: image Alec%20Baldwin%20Cannes%202012.jpg?
# False
# Question: 5
# Does the thing you are looking for have the attribute: image John%20Krasinski%202018.png?
# False
# Question: 6
# Does the thing you are looking for have the attribute: image Olivia%20Wilde%20at%20the%20Red%20Carpet%20Premiere%20of%20A%20Vigilante%20during%20SXSW%202018%20%2840704996872%29%20%28cropped%29.jpg?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image Rachel%20Weisz%20Cannes%202015%202.jpg?
# False
# Your Answer is: Stanley_Tucci
# Win!
#
#  <http://yago-knowledge.org/resource/Scarlett_Johansson>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# Question: 3
# Does the thing you are looking for have the attribute: alumniOf Columbia_University?
# False
# Question: 4
# Does the thing you are looking for have the attribute: award Ellis_Island_Medal_of_Honor?
# False
# Question: 5
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image Aretha%20Franklin%201968.jpg?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image Kim%20Kardashian%202018%205.png?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Official%20photo%20of%20Speaker%20Nancy%20Pelosi%20in%202019.jpg?
# False
# Question: 10
# Does the thing you are looking for have the attribute: image Scarlett%20Johansson%20by%20Gage%20Skidmore%202%20%28cropped%29%20%28cropped%29.jpg?
# True
# Your Answer is: Scarlett_Johansson
# Win!
#
#  <http://yago-knowledge.org/resource/Vin_Diesel>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image Kobe%20Bryant%202015.jpg?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image LeBron%20James%20at%20GSW.jpg?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image Prince%20at%20Coachella%20crop.jpg?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Sylvester%20Stallone%202012.jpg?
# False
# Question: 10
# Does the thing you are looking for have the attribute: image Tom%20Hardy%20by%20Gage%20Skidmore.jpg?
# False
# Your Answer is: Vin_Diesel
# Win!
#
#  <http://yago-knowledge.org/resource/Michael_Jordan>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# Question: 6
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# Question: 7
# Does the thing you are looking for have the attribute: image 20160917%20Tom%20Brady%20at%20Michigan%20Stadium.jpg?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image Emma%20Stone%202014.jpg?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Michael%20Jordan%20in%202014.jpg?
# True
# Your Answer is: Michael_Jordan
# Win!
#
#  <http://yago-knowledge.org/resource/Robin_Williams>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# Question: 4
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actress?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Comedian?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image BettyWhiteJune09.jpg?
# False
# Your Answer is: Robin_Williams
# Win!
#
#  <http://yago-knowledge.org/resource/Britney_Spears>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# Question: 5
# Does the thing you are looking for have the attribute: memberOf American_Philosophical_Society?
# False
# Question: 6
# Does the thing you are looking for have the attribute: image Britney%20Spears%2C%20Roundhouse%2C%20London%20%28Apple%20Music%20Festival%202016%29%20%2830072929931%29%20%28cropped%29.jpg?
# True
# Your Answer is: Britney_Spears
# Win!
#
#  <http://yago-knowledge.org/resource/Tom_Hardy>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image Kobe%20Bryant%202015.jpg?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image LeBron%20James%20at%20GSW.jpg?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image Prince%20at%20Coachella%20crop.jpg?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Sylvester%20Stallone%202012.jpg?
# False
# Question: 10
# Does the thing you are looking for have the attribute: image Tom%20Hardy%20by%20Gage%20Skidmore.jpg?
# True
# Your Answer is: Tom_Hardy
# Win!
#
#  <http://yago-knowledge.org/resource/Kobe_Bryant>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image Kobe%20Bryant%202015.jpg?
# True
# Your Answer is: Kobe_Bryant
# Win!
#
#  <http://yago-knowledge.org/resource/Sylvester_Stallone>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# Question: 6
# Does the thing you are looking for have the attribute: image Kobe%20Bryant%202015.jpg?
# False
# Question: 7
# Does the thing you are looking for have the attribute: image LeBron%20James%20at%20GSW.jpg?
# False
# Question: 8
# Does the thing you are looking for have the attribute: image Prince%20at%20Coachella%20crop.jpg?
# False
# Question: 9
# Does the thing you are looking for have the attribute: image Sylvester%20Stallone%202012.jpg?
# True
# Your Answer is: Sylvester_Stallone
# Win!
#
#  <http://yago-knowledge.org/resource/Elizabeth_II>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# Question: 2
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File E:\Conda\lib\socket.py:832, in create_connection(address, timeout, source_address)
#     831     sock.bind(source_address)
# --> 832 sock.connect(sa)
#     833 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 9>()
#      30 PosFilters, NegFilters = generateBotQuestion(listOfPred, listOfObj, 0, subject)
#      32 # number of popular entities left
# ---> 33 left = numberleft(PosFilters, NegFilters)
#      35 # run query
#      36 query = updateQuery(left/2,PosFilters, NegFilters)
#
# Input In [10], in numberleft(PosFilters, NegFilters)
#      11 sparql.setQuery(query)
#      12 sparql.setReturnFormat(JSON)
# ---> 13 qres = sparql.query().convert()
#      14 for r in qres["results"]["bindings"]:
#      15     left= (r["count"]["value"])
#
# File E:\Conda\lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File E:\Conda\lib\site-packages\SPARQLWrapper\Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File E:\Conda\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File E:\Conda\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File E:\Conda\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File E:\Conda\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File E:\Conda\lib\urllib\request.py:1375, in HTTPHandler.http_open(self, req)
#    1374 def http_open(self, req):
# -> 1375     return self.do_open(http.client.HTTPConnection, req)
#
# File E:\Conda\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344 try:
#    1345     try:
# -> 1346         h.request(req.get_method(), req.selector, req.data, headers,
#    1347                   encode_chunked=req.has_header('Transfer-encoding'))
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
#
# File E:\Conda\lib\http\client.py:1279, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1276 def request(self, method, url, body=None, headers={}, *,
#    1277             encode_chunked=False):
#    1278     """Send a complete request to the server."""
# -> 1279     self._send_request(method, url, body, headers, encode_chunked)
#
# File E:\Conda\lib\http\client.py:1325, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1321 if isinstance(body, str):
#    1322     # RFC 2616 Section 3.7.1 says that text default has a
#    1323     # default charset of iso-8859-1.
#    1324     body = _encode(body, 'body')
# -> 1325 self.endheaders(body, encode_chunked=encode_chunked)
#
# File E:\Conda\lib\http\client.py:1274, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1272 else:
#    1273     raise CannotSendHeader()
# -> 1274 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File E:\Conda\lib\http\client.py:1034, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1032 msg = b"\r\n".join(self._buffer)
#    1033 del self._buffer[:]
# -> 1034 self.send(msg)
#    1036 if message_body is not None:
#    1037
#    1038     # create a consistent interface to message_body
#    1039     if hasattr(message_body, 'read'):
#    1040         # Let file-like take precedence over byte-like.  This
#    1041         # is needed to allow the current position of mmap'ed
#    1042         # files to be taken into account.
#
# File E:\Conda\lib\http\client.py:974, in HTTPConnection.send(self, data)
#     972 if self.sock is None:
#     973     if self.auto_open:
# --> 974         self.connect()
#     975     else:
#     976         raise NotConnected()
#
# File E:\Conda\lib\http\client.py:945, in HTTPConnection.connect(self)
#     943 def connect(self):
#     944     """Connect to the host and port specified in __init__."""
# --> 945     self.sock = self._create_connection(
#     946         (self.host,self.port), self.timeout, self.source_address)
#     947     self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     949     if self._tunnel_host:
#
# File E:\Conda\lib\socket.py:832, in create_connection(address, timeout, source_address)
#     830 if source_address:
#     831     sock.bind(source_address)
# --> 832 sock.connect(sa)
#     833 # Break explicitly a reference cycle
#     834 err = None
#
# KeyboardInterrupt:
